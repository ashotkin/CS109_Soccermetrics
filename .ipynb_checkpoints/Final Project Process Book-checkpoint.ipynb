# %% [markdown]
# # CS 109 Final Project
# MLS Soccer Analysis

# %%
import urllib2
from bs4 import BeautifulSoup
import pandas as pd

# %%
# I didn't know how to scrape before. So I used this webpage as a reference:
# http://palewi.re/posts/2008/04/20/python-recipe-grab-a-page-scrape-a-table-download-a-file/

mainpage = "http://www.mlssoccer.com/stats/season"

# the table is continued on other pages
#urls = [mainpage + '?page={}'.format(i) for i in range(1,26)]
#urls.insert(0,mainpage)

playerpage = "http://www.mlssoccer.com/stats/season?"
players = pd.DataFrame(columns=('Player', 'Year', 'Club', 'Position', 'GP', 'GS', 'MINS', 'G', 'A', 'SHTS', 'SOG', 'GWG', 'PKG/A', 'HmG', 'RdG', 'G/90min', 'SC%'))
i=0
for year in range(1996,2015):
    pageNumber = 0
    last_page = 1
    while pageNumber <= last_page:
        page = BeautifulSoup(urllib2.urlopen(playerpage + "season_year=" + str(year) + "&page=" + str(pageNumber)).read())
        #last_page = int(page.find('li', {"class":"pager-current last"}).contents[0])
        if pageNumber == 0:
            last_page = int(str(page.find('li', {"class":"pager-last last"}).contents[0]).split('=')[3].split('&')[0])
        pageNumber+=1
        table = page.find('table')
        for row in table.findAll('tr')[1:]:
            col = row.findAll('td')
            player = col[0].string
            club = col[1].string
            pos = col[2].string
            gp = int(col[3].string)
            gs = int(col[4].string)
            mins = int(col[5].string)
            g = int(col[6].string)
            a = int(col[7].string)
            shts = int(col[8].string)
            sog = int(col[9].string)
            gwg = int(col[10].string)
            pkga = col[11].string
            hmg = int(col[12].string)
            rdg = int(col[13].string)
            g90min = float(col[14].string)
            sc = float(col[15].string)
            players.loc[i] = [player, year, club, pos, gp, gs, mins, g, a, shts, sog, gwg, pkga, hmg, rdg, g90min, sc]
            i+=1
            
players
# Out:
#                    Player  Year Club Position  GP  GS  MINS   G   A SHTS SOG  \
# 0            Roy Lassiter  1996   TB        F  30  30  2580  27   4   76  49
# 1          Raul Diaz Arce  1996   DC        F  28  28  2351  23   2  100  49
# 2         Eduardo Hurtado  1996   LA        F  26  26  2323  21   7   87  56
# 3                   Preki  1996   KC        M  32  32  2880  18  13  140  61
# 4           Brian McBride  1996  CLB        F  28  28  2307  17   3   79  44
# 5            Steve Rammel  1996   DC        F  26  20  1649  14   3   54  32
# 6        Vitalis Takawira  1996   KC        F  28  25  2233  13   7   70  48
# 7             Jason Kreis  1996  DAL        M  31  29  2564  13   5   90  41
# 8              Paul Bravo  1996   SJ        M  31  31  2654  13   5   58  29
# 9       Giovanni Savarese  1996  MET        F  26  15  1576  13   1   49  32
# 10            Pete Marino  1996  CLB        F  29  18  1700  11   4   52  36
# 11            Jean Harbor  1996  COL        F  29  27  2111  11   4   61  33
# 12          Joe-Max Moore  1996   NE        F  14  14  1238  11   1   36  19
# 13           Eric Wynalda  1996   SJ        F  27  26  2326  10  13   68  38
# 14       Missael Espinoza  1996   SJ        F  26  26  2310  10   5   54  30
# 15             Mark Chung  1996   KC        M  32  32  2847   8   9   81  40
# 16         Shaun Bartlett  1996  COL        F  26  26  2252   8   7   88  39
# 17     Giuseppe Galderisi  1996   TB        F  25  22  1961   7   8   57  25
# 18             Cobi Jones  1996   LA        M  28  27  2375   7   4   48  24
# 19         Marcelo Balboa  1996  COL        D  18  16  1525   7   2   28  14
# 20          Steve Ralston  1996   TB        M  31  31  2762   7   2   24  12
# 21             Adrian Paz  1996  CLB        M  27  19  1802   6  10   48  25
# 22         Alberto Naveda  1996   NE        F  25  20  1734   6   7   65  35
# 23       Harut Karapetyan  1996   LA        F  28  23  1860   6   6   62  30
# 24           Hugo Sanchez  1996  DAL        F  23  21  1708   6   3   40  23
# 25            Mo Johnston  1996   KC      M-F  29  29  2573   6   3   54  28
# 26        Antony De Avila  1996  MET        F   8   7   650   6   2   20  13
# 27    Mauricio Cienfuegos  1996   LA        M  28  27  2405   5  11   47  26
# 28         Gerell Elliott  1996  DAL        F  20  16  1523   5   7   43  24
# 29         Martin Vasquez  1996   TB        M  31  31  2700   5   6   51  25
# ...                   ...   ...  ...      ...  ..  ..   ...  ..  ..  ...  ..
# 8045          Dan Kennedy  2014  CHV       GK  33  33  2957   0   0    0   0
# 8046         Sean Johnson  2014  CHI       GK  33  33  2970   0   0    0   0
# 8047          Luis Robles  2014   NY       GK  34  34  3060   0   0    0   0
# 8048          Stefan Frei  2014  SEA       GK  34  34  3060   0   0    0   0
# 8049          Steve Clark  2014  CLB       GK  34  34  3060   0   0    0   0
# 8050        Eric Kronberg  2014   KC       GK  20  20  1800   0   0    0   0
# 8051       Raul Fernandez  2014  DAL       GK  21  20  1818   0   0    0   0
# 8052         Heath Pearce  2014  MTL        D  23  20  1822   0   0    3   0
# 8053         Leo Gonzalez  2014  SEA        D  23  20  1836   0   0    2   1
# 8054       Steve Birnbaum  2014   DC        D  21  21  1890   0   0   11   1
# 8055      Ibrahim Sekagya  2014   NY        D  25  23  1947   0   0    6   0
# 8056      Jermaine Taylor  2014  HOU        D  24  23  2012   0   0    9   0
# 8057       Matteo Ferrari  2014  MTL        D  25  25  2148   0   0    3   0
# 8058           Tally Hall  2014  HOU       GK  24  24  2150   0   0    0   0
# 8059         Nick Rimando  2014  RSL       GK  24  24  2160   0   0    0   0
# 8060           Donny Toia  2014  CHV        D  27  24  2240   0   0   13   3
# 8061       Bakary Soumare  2014  CHI        D  26  25  2275   0   0    4   1
# 8062          Clint Irwin  2014  COL       GK  26  25  2336   0   0    0   0
# 8063         Tony Beltran  2014  RSL        D  29  28  2483   0   0    7   0
# 8064         Jaime Penedo  2014   LA       GK  29  29  2610   0   0    0   0
# 8065          Zac MacMath  2014  PHI       GK  29  29  2610   0   0    0   0
# 8066    Michael Parkhurst  2014  CLB        D  33  32  2806   0   0    4   1
# 8067       Andrew Farrell  2014   NE        D  32  32  2840   0   0    6   3
# 8068     Donovan Ricketts  2014  POR       GK  32  32  2861   0   0    0   0
# 8069   Bobby Shuttleworth  2014   NE       GK  32  32  2880   0   0    0   0
# 8070          Dan Kennedy  2014  CHV       GK  33  33  2957   0   0    0   0
# 8071         Sean Johnson  2014  CHI       GK  33  33  2970   0   0    0   0
# 8072          Luis Robles  2014   NY       GK  34  34  3060   0   0    0   0
# 8073          Stefan Frei  2014  SEA       GK  34  34  3060   0   0    0   0
# 8074          Steve Clark  2014  CLB       GK  34  34  3060   0   0    0   0
#
#      GWG PKG/A HmG RdG G/90min   SC%
# 0      4   3/3  19   8    0.94  35.5
# 1      4   4/4  15   8    0.88    23
# 2      6   2/3  13   8    0.81  24.1
# 3      3   7/8  14   4    0.56  12.9
# 4      3   3/4  12   5    0.66  21.5
# 5      6   0/0  11   3    0.76  25.9
# 6      3   0/0  10   3    0.52  18.6
# 7      3   0/0   7   6    0.46  14.4
# 8      4   1/1   3  10    0.44  22.4
# 9      3   1/1   8   5    0.74  26.5
# 10     1   0/0   4   7    0.58  21.2
# 11     0   3/3   7   4    0.47    18
# 12     4   3/3   8   3     0.8  30.6
# 13     3   2/2   6   4    0.39  14.7
# 14     3   0/0   7   3    0.39  18.5
# 15     2   0/0   4   4    0.25   9.9
# 16     3   0/0   5   3    0.32   9.1
# 17     1   0/0   4   3    0.32  12.3
# 18     0   0/0   1   6    0.27  14.6
# 19     1   0/0   4   3    0.41    25
# 20     5   0/0   5   2    0.23  29.2
# 21     1   1/1   4   2     0.3  12.5
# 22     1   0/0   4   2    0.31   9.2
# 23     1   0/0   4   2    0.29   9.7
# 24     1   1/1   5   1    0.32    15
# 25     1   0/0   4   2    0.21  11.1
# 26     1   0/0   5   1    0.83    30
# 27     2   2/3   4   1    0.19  10.6
# 28     1   0/0   4   1     0.3  11.6
# 29     2   0/0   2   3    0.17   9.8
# ...   ..   ...  ..  ..     ...   ...
# 8045   0   0/0   0   0       0     0
# 8046   0   0/0   0   0       0     0
# 8047   0   0/0   0   0       0     0
# 8048   0   0/0   0   0       0     0
# 8049   0   0/0   0   0       0     0
# 8050   0   0/0   0   0       0     0
# 8051   0   0/0   0   0       0     0
# 8052   0   0/0   0   0       0     0
# 8053   0   0/0   0   0       0     0
# 8054   0   0/0   0   0       0     0
# 8055   0   0/0   0   0       0     0
# 8056   0   0/0   0   0       0     0
# 8057   0   0/0   0   0       0     0
# 8058   0   0/0   0   0       0     0
# 8059   0   0/0   0   0       0     0
# 8060   0   0/0   0   0       0     0
# 8061   0   0/0   0   0       0     0
# 8062   0   0/0   0   0       0     0
# 8063   0   0/0   0   0       0     0
# 8064   0   0/0   0   0       0     0
# 8065   0   0/0   0   0       0     0
# 8066   0   0/0   0   0       0     0
# 8067   0   0/0   0   0       0     0
# 8068   0   0/0   0   0       0     0
# 8069   0   0/0   0   0       0     0
# 8070   0   0/0   0   0       0     0
# 8071   0   0/0   0   0       0     0
# 8072   0   0/0   0   0       0     0
# 8073   0   0/0   0   0       0     0
# 8074   0   0/0   0   0       0     0
#
# [8075 rows x 17 columns]

# %%
players.to_csv('players.csv')

# %%
players2 = pd.read_csv('players.csv')
players2 = players2.drop('Unnamed: 0', 1)
players2.head()
# Out:
#             Player  Year Club Position  GP  GS  MINS   G   A  SHTS  SOG  GWG  \
# 0     Roy Lassiter  1996   TB        F  30  30  2580  27   4    76   49    4
# 1   Raul Diaz Arce  1996   DC        F  28  28  2351  23   2   100   49    4
# 2  Eduardo Hurtado  1996   LA        F  26  26  2323  21   7    87   56    6
# 3            Preki  1996   KC        M  32  32  2880  18  13   140   61    3
# 4    Brian McBride  1996  CLB        F  28  28  2307  17   3    79   44    3
#
#   PKG/A  HmG  RdG  G/90min   SC%
# 0   3/3   19    8     0.94  35.5
# 1   4/4   15    8     0.88  23.0
# 2   2/3   13    8     0.81  24.1
# 3   7/8   14    4     0.56  12.9
# 4   3/4   12    5     0.66  21.5

# %%
int(str(page.find('li', {"class":"pager-last last"}).contents[0]).split('=')[3].split('&')[0])
# Out:
# 25

# %%
teampage = 'http://www.mlssoccer.com/stats/team'

teams = pd.DataFrame(columns=('Club', 'Year', 'Season', 'GP', 'G', 'A', 'SHT', 'SOG', 'FC', 'FS', 'OFF', 'CK', 'PKG', 'PKA'))


for year in range(1996,2015):
    pageNumber = 0
    for season in ['REG', 'PS']:
        
        i = len(teams['Club'])
        
        page = BeautifulSoup(urllib2.urlopen(teampage + "?season_year=" + str(year) + "&season_type=" + season).read())
        table = page.find('table')
        for row in table.findAll('tr')[1:]:
            col = row.findAll('td')
            club = col[0].string
            gp = int(col[1].string)
            g = int(col[2].string)
            a = int(col[3].string)
            sht = int(col[4].string)
            sog = int(col[5].string)
            fc = int(col[6].string)
            fs = int(col[7].string)
            off = int(col[8].string)
            ck = int(col[9].string)
            pkg = int(col[10].string)
            pka = int(col[11].string)
            
            teams.loc[i] = [club, year, season, gp, g, a, sht, sog, fc, fs, off, ck, pkg, pka]
            i+=1
teams

# %%
resultpage = "http://www.mlssoccer.com/results/"


results = pd.DataFrame(columns=('Year', 'Club', 'Date', 'Versus', 'Club Score', 'Opposing Score', 'W/L/D'))
n=0
for year in range(2011,2015):
    page = BeautifulSoup(urllib2.urlopen(resultpage + str(year)).read())
    table = page.find('table')
    for row in table.findAll('tr')[1:]:
        col = row.findAll('td')
        for i in range(len(col)):
            if i == 0:
                team = col[i]
                clubsplit = str(team).split('\n')
                club = clubsplit[2][10:-16]
            else:
                data = str(col[i]).split('>')
                winloss = data[2][0]
                date =  data[3][:-4]
                versussplit = data[4].split()
                versus = ' '
                for j in range(len(versussplit)):
                    versus = versus + ' ' + versussplit[j]
                versus = versus[5:-4]
                split = data[5].split()
                score1 = int(split[0])
                score2 = int(split[2])
                

                if winloss == 'W':
                    if score1<score2:
                        score = score2
                        scoreopp = score1
                    else:
                        score = score1
                        scoreopp = score2
                elif winloss == 'L':
                    if score1<score2:
                        score = score1
                        scoreopp = score2
                    else:
                        score = score2
                        scoreopp = score1
                else:
                    score = score1
                    scoreopp = score2
                    
                results.loc[n] = [year, club, date, versus, score, scoreopp, winloss]
                n+=1

            
results

# %%
salaries = pd.DataFrame(columns = ('Club', 'Last Name', 'First Name', 'Pos', 'Base Salary', 'Guaranteed Compensation', 'Year'))

for year in range(2007,2015):
    
    n = len(salaries['Club'])
    
    url = 'http://www.hcs.harvard.edu/~hub/' + str(year) + '%20salaries%20by%20player.csv'

    data = pd.read_csv(url)


    for x in range(6,(len(data.columns))):
        del data['Unnamed: ' + str(x)]
 
    data.columns = ['Club', 'Last Name', 'First Name', 'Pos', 'Base Salary', 'Guaranteed Compensation']
    
    years = [year for y in range(len(data['Club']))]
    
    data['Year'] = years
    
    for z in range(len(data['Club'])):
        salaries.loc[n] = data.loc[z]
        n+=1

salaries
# Out:
#        Club        Last Name      First Name  Pos            Base Salary  \
# 0        DC          Addlery        Nicholas    F  $           36,000.00
# 1        LA         Albright           Chris  M-D   $         142,500.00
# 2        NY         Altidore          Josmer    F  $           85,000.00
# 3       DAL          Alvarez          Arturo    M  $           32,819.00
# 4        NY            Angel      Juan Pablo    F    $      1,500,000.00
# 5        DC           Arguez           Bryan  M-D  $           45,000.00
# 6       CHI            Armas           Chris    M   $         225,000.00
# 7        KC           Arnaud            Davy    M   $         100,000.00
# 8       CHV           Arvizu           David    F  $           33,000.00
# 9       HOU             Ashe           Corey    M  $           30,000.00
# 10      TFC    Attakora-Gyan            Nana    D  $           12,900.00
# 11      COL        Ballouchy           Mehdi    M  $           70,000.00
# 12      CHI           Banner         Michael    M  $           12,900.00
# 13      CHI          Barrett            Chad    F  $           41,212.50
# 14      HOU          Barrett            Wade    D   $         141,750.00
# 15      RSL        Beckerman            Kyle    M   $         120,000.00
# 16       LA          Beckham           David    M    $      5,500,000.08
# 17      RSL          Besagno         Nikolas    M  $           75,000.00
# 18      CHI           Blanco      Cuauhtemoc    F    $      2,492,316.00
# 19      CHV        Bornstein        Jonathan    D  $           57,500.00
# 20       DC          Boswell          Robert    D  $           30,870.00
# 21      DAL           Botero  Juan Sebastian    M  $           12,900.00
# 22      TFC           Boyens          Andrew    D  $           30,000.00
# 23      TFC             Braz            Adam    D  $           67,200.00
# 24      TFC          Brennan             Jim    D   $         150,000.00
# 25      CHV           Brooks         Desmond    D  $           12,900.00
# 26      CHI            Brown            C.J.    D   $         106,391.00
# 27      RSL            Brown            Kyle    F  $           17,700.00
# 28      RSL            Brown           Chris  M-F  $           70,000.00
# 29       LA           Buddle           Edson    F   $         140,000.00
# ...     ...              ...             ...  ...                    ...
# 3778    TOR           Warner          Collen  M-F      $      115,500.00
# 3779    VAN           Waston         Kendall    D      $      199,992.00
# 3780    CHI           Watson            Matt    M     $        71,663.00
# 3781    DAL           Watson        JeVaughn    M      $      110,000.00
# 3782  NYCFC   Watson-Siriboe           Kwame    D     $        55,000.00
# 3783    COL            Watts           Jared    M     $        36,500.00
# 3784    SEA           Weaver             Cam    F     $        48,504.00
# 3785    POR            Weber          Andrew   GK     $        48,500.04
# 3786    PHI           Wenger          Andrew  D/F      $      140,000.00
# 3787    PHI          Wheeler           Aaron    F     $        48,825.00
# 3788    PHI            White           Ethan    D     $        80,000.00
# 3789    TOR         Wiedeman          Andrew    F     $        60,500.00
# 3790    CLB             Wiet            Matt    D     $        48,500.00
# 3791    CLB         Williams            Josh    D      $      125,000.00
# 3792    PHI         Williams         Sheanon    F      $      125,000.00
# 3793     DC           Willis             Joe   GK     $        48,825.00
# 3794    RSL          Wingert           Chris    D      $      163,590.00
# 3795   POOL          Withrow          Daniel   GK     $        36,504.00
# 3796     SJ      Wondolowski           Chris    M      $      600,000.00
# 3797     NY  Wright-Phillips         Bradley    F      $      330,000.00
# 3798    COL            Wynne         Marvell    D      $      200,000.00
# 3799    SEA           Yedlin         DeAndre    D     $        80,000.00
# 3800    POR          Zakuani           Steve    F      $      120,000.00
# 3801     LA           Zardes           Gyasi    F      $      125,000.00
# 3802    CHV         Zavaleta            Eriq    F     $        75,000.00
# 3803    POR         Zemanski             Ben    M     $        80,850.00
# 3804    DAL         Zendejas       Alejandro    F     $        36,504.00
# 3805    DAL        Zimmerman          Walker    D     $        80,000.00
# 3806     KC            Zizzo             Sal    F     $        77,000.00
# 3807     KC             Zusi          Graham  F-M      $      600,000.00
#
#           Guaranteed Compensation  Year
# 0     $                 36,000.00  2007
# 1      $               142,500.00  2007
# 2      $               108,333.00  2007
# 3     $                 46,019.00  2007
# 4       $            1,593,750.00  2007
# 5     $                 76,200.00  2007
# 6      $               225,000.00  2007
# 7      $               101,875.00  2007
# 8     $                 40,500.00  2007
# 9     $                 30,000.00  2007
# 10    $                 12,900.00  2007
# 11    $                 88,000.00  2007
# 12    $                 12,900.00  2007
# 13    $                 48,712.50  2007
# 14     $               141,750.00  2007
# 15     $               122,500.00  2007
# 16      $            6,500,000.04  2007
# 17     $               111,500.00  2007
# 18      $            2,666,778.00  2007
# 19    $                 57,500.00  2007
# 20    $                 30,870.00  2007
# 21    $                 12,900.00  2007
# 22    $                 47,500.00  2007
# 23    $                 74,950.00  2007
# 24     $               158,000.00  2007
# 25    $                 12,900.00  2007
# 26     $               106,391.00  2007
# 27    $                 17,700.00  2007
# 28    $                 70,000.00  2007
# 29     $               150,000.00  2007
# ...                           ...   ...
# 3778       $           143,000.00  2014
# 3779       $           201,242.00  2014
# 3780      $             82,664.99  2014
# 3781       $           126,875.00  2014
# 3782      $             56,666.67  2014
# 3783      $             36,500.00  2014
# 3784      $             49,004.00  2014
# 3785      $             48,500.04  2014
# 3786       $           242,000.00  2014
# 3787      $             48,825.00  2014
# 3788      $             80,000.00  2014
# 3789      $             70,500.00  2014
# 3790      $             48,500.00  2014
# 3791       $           125,000.00  2014
# 3792       $           130,500.00  2014
# 3793      $             48,825.00  2014
# 3794       $           170,590.00  2014
# 3795      $             36,504.00  2014
# 3796       $           650,000.00  2014
# 3797       $           372,500.00  2014
# 3798       $           285,000.00  2014
# 3799      $             92,000.00  2014
# 3800       $           120,000.00  2014
# 3801       $           198,000.00  2014
# 3802       $           105,600.00  2014
# 3803      $             83,350.00  2014
# 3804      $             53,170.67  2014
# 3805       $           160,100.00  2014
# 3806      $             91,045.71  2014
# 3807       $           631,388.89  2014
#
# [3808 rows x 7 columns]
