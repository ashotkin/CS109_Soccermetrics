# %% [markdown]
# # CS 109 Final Project
# MLS Soccer Analysis

# %% [markdown]
# Jack Davison, Cara Dowell, Scott Johnson, Aaron Shotkin

# %% [markdown]
# All data available at:
#
# https://drive.google.com/a/college.harvard.edu/file/d/0B8cG0-y6G6E1X0xWMWlvX0hEOUU/view?usp=sharing
#
# To access: download zip file, then extract files into the same folder as this iPython Notebook.
#
# The CSV's included should be:
#
# -These are the training/testing/validation sets that include the score differences and both teams’ statistics:
#
# finalResultsA.csv
#
# finalResultsB.csv
#
# finalResultsC.csv
#
# -Stored goalkeeper minutes:
#
# goalkeeper_games.csv
#
# -Stored goalkeeper stats:
#
# goalkeepers.csv
#
# -Stored the players’ minutes:
#
# player_gamesA.csv
#
# player_gamesB.csv
#
# -Player season stats:
#
# players.csv
#
# -Game results:
#
# results.csv
#
# -Game results together with player minutes:
#
# resultsWithPlayers.csv
#
# -Players and their yearly salaries:
#
# salaries.csv
#
# -These are the same as the finaResults CSV’s, but only with information on a single team at a time and the opposing goalie:
#
# ScoreResultsA.csv
#
# ScoreResultsB.csv
#
# ScoreResultsC.csv
#
# -Converts team abbreviations to full team names:
#
# team-abbrev-verbose.csv
#
# -Season statistics for each team:
#
# teams.csv

# %%
import urllib2
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import re
# %matplotlib inline 

#We don't need all of these, but it doesn't hurt to import them anyways
import sklearn
import sklearn.datasets
import sklearn.cross_validation
import sklearn.decomposition
import sklearn.grid_search 
import sklearn.neighbors
import sklearn.metrics
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import cross_val_score

# %% [markdown]
# ## Scraping the data into CSVs

# %%
## This cell scrapes player season statistics for creating initial player profiles
###### NEVER RUN THIS CELL AGAIN ######

# I didn't know how to scrape before. So I used this webpage as a reference:
# http://palewi.re/posts/2008/04/20/python-recipe-grab-a-page-scrape-a-table-download-a-file/

mainpage = "http://www.mlssoccer.com/stats/season"

# the table is continued on other pages
#urls = [mainpage + '?page={}'.format(i) for i in range(1,26)]
#urls.insert(0,mainpage)

playerpage = "http://www.mlssoccer.com/stats/season?"
players = pd.DataFrame(columns=('Player', 'Year', 'Club', 'Position', 'GP', 'GS', 'MINS', 'G', 'A', 'SHTS', 'SOG', 'GWG', 'PKG/A', 'HmG', 'RdG', 'G/90min', 'SC%'))
i=0
for year in range(1996,2015):
    pageNumber = 0
    last_page = 0
    while pageNumber <= last_page:
        page = BeautifulSoup(urllib2.urlopen(playerpage + "season_year=" + str(year) + "&page=" + str(pageNumber)).read(), 'html.parser')
        if pageNumber == 0:
            last_page = int(str(page.find('li', {"class":"pager-last last"}).contents[0]).split('=')[3].split('&')[0])
        pageNumber+=1
        table = page.find('table')
        for row in table.findAll('tr')[1:]:
            col = row.findAll('td')
            player = col[0].string
            club = col[1].string
            pos = col[2].string
            gp = int(col[3].string)
            gs = int(col[4].string)
            mins = int(col[5].string)
            g = int(col[6].string)
            a = int(col[7].string)
            shts = int(col[8].string)
            sog = int(col[9].string)
            gwg = int(col[10].string)
            pkga = col[11].string
            hmg = int(col[12].string)
            rdg = int(col[13].string)
            g90min = float(col[14].string)
            sc = float(col[15].string)
            players.loc[i] = [player, year, club, pos, gp, gs, mins, g, a, shts, sog, gwg, pkga, hmg, rdg, g90min, sc]
            i+=1
            
players

# %%
## This code saves the players dataframe as a csv for future use
##### DON'T RUN THIS ONE EITHER
players.to_csv('players.csv')

# %%
##Don't run again
##this code sets up the player_games data frame, for keeping track of players' minutes in each game

player_games = pd.DataFrame(columns=('Name','Date','Club','Minutes'))
root_player_URL = "http://www.mlssoccer.com/players/"
f = lambda x: 'NULL' if len(x) == 0 else x[0]

# %%
## This code for scraping the MLS data on what players played in each game took an entire day to run and required manual fixes to any player
## that caused an issue with the scraping and so data should in the future be loaded in from the appropriate CSV and not re-scraped.

playerlist = list(set(players["Player"].tolist()))
## These players aren't on the MLS site and so we are exlcuding them from this process
ignore_list = ["Rafhinha","Lyle Martin","TOR","Aaron Ponce","Marcos Mondaini","Rodolfo Espinoza","Cristian Fernandez","Dario Delgado","Eduardo Fernandez","DAL","Junior Burgos","Tico-Tico","Oscar Recio","Cyprian Hedrick","Santiago Hirsig","Tiyi Shipalane","Gege Soriola","Andrew Quinn","Barry Rice","Syamsir Alam","Mike Holody","J.P. Rodrigues","Steve Purdy","Paulo Araujo Jr.","Erick","Anthony Obodai","Kenny Mansally","Tiago Ulisses","Narciso Fernandes","Richard Marquez","Missael Espinoza","Rafael Marquez","Alexandre Emerson","Maksim Usanov"]
## this method scrapes the page for one player's minutes in his entire career
def addPlayerToResults(name):
    #set the iterator to the top of the df index
    j = len(player_games)
    if name not in ignore_list:
        #try-except logic so that we can pick up the process from where we left off and not rerun from the beginning
        try:
            nameURL = name.lower().replace(' ','-').replace('.','').replace('\'','')
            page = BeautifulSoup(urllib2.urlopen(root_player_URL + nameURL).read(), 'html.parser')
            if not "This player does not currently have a game log." in unicode(page):
                tablediv = [tree for tree in page.findAll("div") if 'class' in tree.attrs.keys() and ("stats-table" in tree.attrs["class"]) and ("Regular Season Game Log" in unicode(tree))][0]
                table = tablediv.findAll("table")[0]
                clubyears = dict()
                for row in table.findAll("tr")[1:]:
                    col = row.findAll("td")
                    date = col[0].string
                    minutes = int(col[4].string)
                    yr = int(date.split('/')[-1])
                    if yr not in clubyears:
                        clubyears[yr] = f(players[players["Player"] == name][players["Year"] == yr]["Club"].tolist())
                    if minutes > 0:
                        player_games.loc[j] = [name,date,clubyears[yr],minutes]
                        j+=1
        except:
            #this prints out the player's name that gave us an error as well as their index in the playerlist
            #so that we can pick up from where we left off
            print name
            print playerlist.index(name)
            raise

#[addPlayerToResults(x) for x in playerlist[2494:]]
#player_games.head()
# Out:
#          Name        Date  Club Minutes
# 0  Chris Korb  10/25/2014  NULL      90
# 1  Chris Korb  10/18/2014  NULL      21
# 2  Chris Korb  10/12/2014  NULL      29
# 3  Chris Korb   10/3/2014  NULL      90
# 4  Chris Korb   9/27/2014  NULL      61

# %%
## Saving the player_games data frame to a csv. We made two csvs so we could push in between.

#player_games.to_csv('player_gamesB.csv')
#len(playerlist)

# %%
## Setting up the goalkeeper dataframe for minutes in each game

goalkeeper_games = pd.DataFrame(columns=('Name','Date','Club','Minutes'))

# %%
## This code for scraping the MLS data on what keeprs played in each game
## DO NOT RERUN

keeperlist = list(set(goalkeepers["Player"].tolist()))
ignore_list = ["Eduardo Fernandez"]
def addKeeperToResults(name):
    j = len(goalkeeper_games)
    if name not in ignore_list:
        try:
            nameURL = name.lower().replace(' ','-').replace('.','').replace('\'','')
            page = BeautifulSoup(urllib2.urlopen(root_player_URL + nameURL).read(), 'html.parser')
            if not "This player does not currently have a game log." in unicode(page):
                tablediv = [tree for tree in page.findAll("div") if 'class' in tree.attrs.keys() and ("stats-table" in tree.attrs["class"]) and ("Regular Season Game Log" in unicode(tree))][0]
                table = tablediv.findAll("table")[0]
                clubyears = dict()
                for row in table.findAll("tr")[1:]:
                    col = row.findAll("td")
                    date = col[0].string
                    minutes = int(col[4].string)
                    yr = int(date.split('/')[-1])
                    if yr not in clubyears:
                        clubyears[yr] = f(goalkeepers[goalkeepers["Player"] == name][goalkeepers["Year"] == yr]["Club"].tolist())
                    if minutes > 0:
                        goalkeeper_games.loc[j] = [name,date,clubyears[yr],minutes]
                        j+=1
        except:
            ## try-except logic to allow us to get info on what player broke the code and pick up from where we left off
            print name
            print keeperlist.index(name)
            raise
            
#[addKeeperToResults(x) for x in keeperlist[31:]]
goalkeeper_games.head()
# Out:
#         Name       Date Club Minutes
# 0  Jay Nolly  8/13/2011  VAN      90
# 1  Jay Nolly   8/7/2011  VAN      90
# 2  Jay Nolly  6/29/2011  VAN      90
# 3  Jay Nolly  5/28/2011  VAN      90
# 4  Jay Nolly  5/14/2011  VAN      90

# %%
## Saving goalkeeper_games as a csv to load later on

#goalkeeper_games.to_csv('goalkeeper_games.csv')

# %%
## This code is for building a teams dataframe of team performance by season
##### DON'T RUN
teampage = 'http://www.mlssoccer.com/stats/team'

teams = pd.DataFrame(columns=('Club', 'Year', 'Season', 'GP', 'G', 'A', 'SHT', 'SOG', 'FC', 'FS', 'OFF', 'CK', 'PKG', 'PKA'))


for year in range(1996,2015):
    for season in ['REG', 'PS']:
        
        i = len(teams['Club'])
        
        page = BeautifulSoup(urllib2.urlopen(teampage + "?season_year=" + str(year) + "&season_type=" + season).read(), 'html.parser')
        table = page.find('table')
        for row in table.findAll('tr')[1:]:
            col = row.findAll('td')
            club = col[0].string
            gp = int(col[1].string)
            g = int(col[2].string)
            a = int(col[3].string)
            sht = int(col[4].string)
            sog = int(col[5].string)
            fc = int(col[6].string)
            fs = int(col[7].string)
            off = int(col[8].string)
            ck = int(col[9].string)
            pkg = int(col[10].string)
            pka = int(col[11].string)
            
            teams.loc[i] = [club, year, season, gp, g, a, sht, sog, fc, fs, off, ck, pkg, pka]
            i+=1
teams

# %%
## This saves the teams dataframe as a csv for later use
##### DON'T RUN
teams.to_csv('teams.csv')

# %%
## This code is for scraping the MLS site for the results of games and storing them in a dataframe
##### DON'T RUN

resultpage = "http://www.mlssoccer.com/results/"


results = pd.DataFrame(columns=('Year', 'Club', 'Date', 'Versus', 'Club Score', 'Opposing Score', 'W/L/D'))
n=0
for year in range(2011,2015):
    page = BeautifulSoup(urllib2.urlopen(resultpage + str(year)).read(), "html.parser")
    table = page.find('table')
    for row in table.findAll('tr')[1:]:
        col = row.findAll('td')
        for i in range(len(col)):
            if i == 0:
                team = col[i]
                clubsplit = str(team).split('\n')
                club = clubsplit[2][10:-16]
            else:
                data = str(col[i]).split('>')
                winloss = data[2][0]
                date =  data[3][:-4]
                versussplit = data[4].split()
                versus = ' '
                for j in range(len(versussplit)):
                    versus = versus + ' ' + versussplit[j]
                versus = versus[5:-4]
                split = data[5].split()
                score1 = int(split[0])
                score2 = int(split[2])
                

                if winloss == 'W':
                    if score1<score2:
                        score = score2
                        scoreopp = score1
                    else:
                        score = score1
                        scoreopp = score2
                elif winloss == 'L':
                    if score1<score2:
                        score = score1
                        scoreopp = score2
                    else:
                        score = score2
                        scoreopp = score1
                else:
                    score = score1
                    scoreopp = score2
                    
                results.loc[n] = [year, club, date, versus, score, scoreopp, winloss]
                n+=1

            
results

# %%
## This saves the results dataframe as a csv for later use
##### DON'T RUN
results.to_csv('results.csv')

# %%
## This code is for scraping salary information from pdfs downloaded from the MLS site into a dataframe
###### DON'T RUN
salaries = pd.DataFrame(columns = ('Club', 'Last Name', 'First Name', 'Pos', 'Base Salary', 'Guaranteed Compensation', 'Year'))

for year in range(2007,2015):
    
    n = len(salaries['Club'])
    
    url = 'http://www.hcs.harvard.edu/~hub/' + str(year) + '%20salaries%20by%20player.csv'

    data = pd.read_csv(url)


    for x in range(6,(len(data.columns))):
        del data['Unnamed: ' + str(x)]
 
    data.columns = ['Club', 'Last Name', 'First Name', 'Pos', 'Base Salary', 'Guaranteed Compensation']
    
    years = [year for y in range(len(data['Club']))]
    
    data['Year'] = years
    
    for z in range(len(data['Club'])):
        salaries.loc[n] = data.loc[z]
        n+=1

salaries

# %%
## This saves the salaries dataframe as a csv for later use
##### DON'T RUN
salaries.to_csv('salaries.csv')

# %%
## This code is for scraping goalkeeper-specific player stats from the MLS site into a dataframe
##### DON'T RUN
goalkeepers = pd.DataFrame(columns = ('Player', 'Year', 'Club', 'POS', 'GP', 'GS', 'MINS', 'SHTS', 'SV', 'GA', 'GAA', 'PKG/A', 'W', 'L', 'T', 'ShO', 'W%', 'Sv%'))
    
i=0
for year in range(1996,2015):
    pageNumber = 0
    last_page = 0
    while pageNumber <= last_page:
        page = BeautifulSoup(urllib2.urlopen("http://www.mlssoccer.com/stats/season?page=" + str(pageNumber) + "&season_year=" + str(year) + "&season_type=REG&team=ALL&group=GOALKEEPING&op=Search&form_id=mls_stats_individual_form").read(), 'html.parser')
        if pageNumber == 0 and page.find('li', {"class":"pager-last last"}) is not None:
            last_page = int(str(page.find('li', {"class":"pager-last last"}).contents[0]).split('=')[3].split('&')[0])
        pageNumber+=1
        table = page.find('table')
        for row in table.findAll('tr')[1:]:
            col = row.findAll('td')
            player = col[0].string
            club = col[1].string
            pos = col[2].string
            gp = int(col[3].string)
            gs = int(col[4].string)
            mins = int(col[5].string)
            shts = int(col[6].string)
            sv = int(col[7].string)
            ga = int(col[8].string)
            gaa = float(col[9].string)
            pkga = col[10].string
            w = int(col[11].string)
            l = int(col[12].string)
            t = int(col[13].string)
            sho = int(col[14].string)
            wperc = int(col[15].string)
            svperc = int(col[16].string)
            goalkeepers.loc[i] = [player, year, club, pos, gp, gs, mins, shts, sv, ga, gaa, pkga, w, l, t, sho, wperc, svperc]
            i+=1

goalkeepers

# %%
## This saves the goalkeeper stats dataframe as a csv for later use
##### DON'T RUN
goalkeepers.to_csv('goalkeepers.csv')

# %% [markdown]
# ## Data Organization

# %%
## loading in the player DF
players = pd.read_csv('players.csv')
players = players.drop('Unnamed: 0', 1)
players = players[players['Year'] >= 2011]
players.head()
# Out:
#             Player  Year Club Position  GP  GS  MINS   G   A  SHTS SOG  GWG  \
# 0     Roy Lassiter  1996   TB        F  30  30  2580  27   4    76  49    4
# 1   Raul Diaz Arce  1996   DC        F  28  28  2351  23   2   100  49    4
# 2  Eduardo Hurtado  1996   LA        F  26  26  2323  21   7    87  56    6
# 3            Preki  1996   KC        M  32  32  2880  18  13   140  61    3
# 4    Brian McBride  1996  CLB        F  28  28  2307  17   3    79  44    3
#
#   PKG/A  HmG  RdG  G/90min   SC%
# 0   3/3   19    8     0.94  35.5
# 1   4/4   15    8     0.88  23.0
# 2   2/3   13    8     0.81  24.1
# 3   7/8   14    4     0.56  12.9
# 4   3/4   12    5     0.66  21.5

# %%
## loading in the teams DF
teams = pd.read_csv('teams.csv')
teams = teams.drop('Unnamed: 0', 1)
teams = teams[teams['Year'] >= 2011]
teams.head()
# Out:
#                      Club  Year Season  GP   G   A  SHT  SOG   FC   FS  OFF  \
# 300   Seattle Sounders FC  2011    REG  34  56  50  443  151  430  408   85
# 301  Sporting Kansas City  2011    REG  34  50  35  488  159  425  416   71
# 302    New York Red Bulls  2011    REG  34  50  53  420  153  420  363  125
# 303           D.C. United  2011    REG  34  49  40  427  151  383  367   98
# 304             LA Galaxy  2011    REG  34  48  43  395  142  396  452   84
#
#       CK  PKG  PKA
# 300  164    6    9
# 301  161    4    4
# 302  200    3    5
# 303  146    8   10
# 304  158    4    4

# %%
## loading in the results DF
results = pd.read_csv('results.csv')
results = results.drop('Unnamed: 0', 1)
##removes duplicate results
results['Team 1'] = np.where(results['Club'] < results['Versus'], results['Club'], results['Versus'])
results['Team 2'] = np.where(results['Club'] > results['Versus'], results['Club'], results['Versus'])
results = results.drop_duplicates(subset=['Year', 'Date', 'Team 1', 'Team 2'])
results.head()
# Out:
#    Year          Club              Date                Versus  Club Score  \
# 0  2011  Chicago Fire  Saturday, Mar 19             FC Dallas           1
# 1  2011  Chicago Fire  Saturday, Mar 26  Sporting Kansas City           3
# 2  2011  Chicago Fire   Saturday, Apr 9   Seattle Sounders FC           1
# 3  2011  Chicago Fire    Friday, Apr 15      Portland Timbers           2
# 4  2011  Chicago Fire    Sunday, Apr 17             LA Galaxy           1
#
#    Opposing Score W/L/D        Team 1                Team 2
# 0               1     D  Chicago Fire             FC Dallas
# 1               2     W  Chicago Fire  Sporting Kansas City
# 2               2     L  Chicago Fire   Seattle Sounders FC
# 3               4     L  Chicago Fire      Portland Timbers
# 4               2     L  Chicago Fire             LA Galaxy

# %%
## This code associated the team name abbreviation with the results DF, and also creates a less verbose date column for each game
## in order to compare them against the player_games and goalkeeper_games dataframe
with open("team-abbrev-verbose.csv", "r") as abbrev:
    pairs = [x.split(',') for x in abbrev.read().split('\n')]
    abbreviations = {k:v for [k,v] in pairs}
    abbreviations.update({v:k for [k,v] in pairs})
results["Team 1 Abbreviation"] = map(lambda x:abbreviations[x], results["Team 1"])
results["Team 2 Abbreviation"] = map(lambda x:abbreviations[x], results["Team 2"])
results["Team 1 Players"] = [[] for x in range(len(results))]
results["Team 2 Players"] = [[] for x in range(len(results))]
monthNum = {'Jan':1, 'Feb':2,'Mar':3,'Apr':4,'May':5,'Jun':6,'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'Dec':12}
results["shortdate"] = map(lambda x, y: str(monthNum[y.split(',')[1].strip().split(' ')[0]]) + "/" + str(y.split(' ')[-1]) + "/" + str(x), results["Year"], results["Date"])
results.head()
#[p for p in results["Team 1 Players"] if p != []]
# Out:
#    Year          Club              Date                Versus  Club Score  \
# 0  2011  Chicago Fire  Saturday, Mar 19             FC Dallas           1
# 1  2011  Chicago Fire  Saturday, Mar 26  Sporting Kansas City           3
# 2  2011  Chicago Fire   Saturday, Apr 9   Seattle Sounders FC           1
# 3  2011  Chicago Fire    Friday, Apr 15      Portland Timbers           2
# 4  2011  Chicago Fire    Sunday, Apr 17             LA Galaxy           1
#
#    Opposing Score W/L/D        Team 1                Team 2  \
# 0               1     D  Chicago Fire             FC Dallas
# 1               2     W  Chicago Fire  Sporting Kansas City
# 2               2     L  Chicago Fire   Seattle Sounders FC
# 3               4     L  Chicago Fire      Portland Timbers
# 4               2     L  Chicago Fire             LA Galaxy
#
#   Team 1 Abbreviation Team 2 Abbreviation Team 1 Players Team 2 Players  \
# 0                 CHI                 DAL             []             []
# 1                 CHI                  KC             []             []
# 2                 CHI                 SEA             []             []
# 3                 CHI                 POR             []             []
# 4                 CHI                  LA             []             []
#
#    shortdate
# 0  3/19/2011
# 1  3/26/2011
# 2   4/9/2011
# 3  4/15/2011
# 4  4/17/2011

# %%
## loading the salaries DF
salaries = pd.read_csv('salaries.csv')
salaries = salaries.drop('Unnamed: 0', 1)
salaries = salaries[salaries['Year'] >= 2011]
salaries.head()
# Out:
#      Club  Last Name   First Name Pos         Base Salary  \
# 1581  COL     Ababio        Eddie   D  $        32,604.00
# 1582  PHI        Adu       Freddy   M   $      475,884.00
# 1583  RSL    Agorsor  Christopher   F  $        32,604.00
# 1584   NY    Agudelo         Juan   F  $        55,000.00
# 1585   KC  Aiyegbusi    Olukorede   D  $        42,000.00
#
#       Guaranteed Compensation  Year
# 1581  $             32,604.00  2011
# 1582   $           594,884.00  2011
# 1583  $             32,604.00  2011
# 1584  $             85,000.00  2011
# 1585  $             42,000.00  2011

# %%
## This cleans the salary data so that we can regress salaries against player traits

salariesCleaned = salaries[['Last Name','First Name','Base Salary','Guaranteed Compensation','Year','Club']]
salariesCleaned['Player'] = map(lambda first, last: " ".join([str(first), str(last)]).strip(), salariesCleaned['First Name'], salariesCleaned['Last Name'])
non_decimal = re.compile(r'[^\d.]+')
salariesCleaned['Salary'] = map(lambda s: int(non_decimal.sub('',s).split('.')[0]), salariesCleaned['Base Salary'])
salariesCleaned['Compensation'] = map(lambda c: int(non_decimal.sub('',c).split('.')[0]), salariesCleaned['Guaranteed Compensation'])
salariesCleaned = salariesCleaned.drop(['Last Name','First Name','Base Salary','Guaranteed Compensation'],1)
salariesCleaned.head()
# Out:
#       Year Club               Player  Salary  Compensation
# 1581  2011  COL         Eddie Ababio   32604         32604
# 1582  2011  PHI           Freddy Adu  475884        594884
# 1583  2011  RSL  Christopher Agorsor   32604         32604
# 1584  2011   NY         Juan Agudelo   55000         85000
# 1585  2011   KC  Olukorede Aiyegbusi   42000         42000

# %%
## loading in the goalkeepers
goalkeepers = pd.read_csv('goalkeepers.csv')
goalkeepers = goalkeepers.drop('Unnamed: 0', 1)
goalkeepers = goalkeepers[goalkeepers['Year'] >= 2011]
goalkeepers.head()
# Out:
#             Player  Year Club POS  GP  GS  MINS  SHTS   SV  GA   GAA PKG/A  \
# 848   Kasey Keller  2011  SEA  GK  34  34  3060   145  110  37  1.09   3/4
# 849   Matt Pickens  2011  COL  GK  34  34  3060   117   77  41  1.21   2/2
# 850     Tally Hall  2011  HOU  GK  34  34  3060   143   99  41  1.21   5/5
# 851      Jon Busch  2011   SJ  GK  33  33  2970   160  113  44  1.33   4/4
# 852  Kevin Hartman  2011  DAL  GK  33  33  2970   124   85  35  1.06   3/3
#
#       W   L   T  ShO  W%  Sv%
# 848  18   7   9    9  53   76
# 849  12   9  13    8  35   66
# 850  12   9  13    6  35   69
# 851   7  12  14    7  21   71
# 852  15  11   7   13  45   69

# %%
## load in player games dataframes and merge them
## we needed two dataframes because my computer's memory couldn't store one dataframe all at one time

player_games = pd.read_csv('player_gamesA.csv')
player_games = player_games.drop('Unnamed: 0', 1)
player_games = player_games.drop_duplicates()

player_gamesB = pd.read_csv('player_gamesB.csv')
player_gamesB = player_gamesB.drop('Unnamed: 0', 1)
player_gamesB = player_gamesB.drop_duplicates()

startDate = pd.Timestamp('2011-01-01 00:00:00')

player_games = pd.concat([player_games,player_gamesB],ignore_index=True)
player_games['Year'] = pd.DatetimeIndex(player_games['Date']).year
player_games = player_games[player_games['Year'] > 2010]

# %%
## Fixes the fact that some people had name changes
names = player_games['Name'].tolist()
newnames = []
for name in names:
    if name == 'Jorge Flores':
        newnames.append('Jorge Villafana')
    elif name == 'Rafa Marquez':
        newnames.append('Rafael Marquez')
    elif name == 'Paulo Jr.':
        newnames.append('Paulo Jr')
    else:  
        newnames.append(name)
            
player_games['Name'] = newnames

names2 = players['Player'].tolist()
newnames2 = []
for name in names2:
    if 'Mansally' in name:
        newnames2.append('Abdoulie Mansally')
    elif 'Sanvezzo' in name:
        newnames2.append('Camilo Sanvezzo')
    elif name == 'Paulo Jr.':
        newnames2.append('Paulo Jr')
    elif name == 'Rafa Marquez':
        newnames2.append('Rafael Marquez')
    else:
        newnames2.append(name)
players['Player'] = newnames2

# %%
## This code just goes through and assigns a club to each player for each game.

#This frame (if run) prints out the index every 10000 iterations, so it's possible
#to track how far along the code is. 
fails = []
positions = []

for index, row in player_games.iterrows():
    player2,year = player_games.ix[index][['Name','Year']]
    sliceOfPlayers = players[players['Player'] == player2]
    sliceOfPlayers = sliceOfPlayers[sliceOfPlayers['Year'] == str(year)] 
    club = sliceOfPlayers['Club'].tolist()
    if club:
        player_games.loc[index,['Club']] = sliceOfPlayers['Club'].tolist()[0]
        positions.append(sliceOfPlayers['Position'].tolist()[0])
    else:
        player_games.loc[index,['Club']] = 'failure'
        positions.append('failure')
        fails.append(index)
    if index % 10000 == 0:
        print index
player_games['POS'] = positions
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000

# %%
## Run this to create the game dictionary
## We chose to only include offensive players because of the dearth of publicly available
## stats on defensive players (such stats ideally would have included information on passing,
## challenges, slide tackles, touches etc)
offense = ['F', 'F-M', 'M', 'M-F']
temp = player_games.drop_duplicates()
temp = temp[temp['POS'].isin(offense)]
temp = temp.groupby(by =['Club','Date','Name'], as_index=False).sum()
teams = set(temp['Club'])
games = {}
for team in teams:
    game = {}
    temp2 = temp[temp['Club'] == team]
    dates = set(temp2['Date'])
    for date in dates:
        players1 = {}
        tempPlayers = temp2[temp2['Date'] == date]
        for player in set(tempPlayers['Name']):
            players1[player] = (tempPlayers[tempPlayers['Name'] == player])['Minutes'].tolist()[0]
        game[date] = players1
    games[team] = game

# %%
## creates keepers dataframe
keepers = player_games.drop_duplicates()
keepers = keepers[keepers['POS'] == 'GK']
keepers = keepers.groupby(by =['Club','Date','Name'], as_index=False).sum()
teams = set(temp['Club'])
goalies = {}
for team in teams:
    goalie = {}
    keepers2 = keepers[keepers['Club'] == team]
    dates = set(keepers2['Date'])
    for date in dates:
        guys = {}
        tempGoalies = keepers2[keepers2['Date'] == date]
        for player1 in set(tempGoalies['Name']):
            guys[player1] = (tempGoalies[tempGoalies['Name'] == player1])['Minutes'].tolist()[0]
        goalie[date] = guys
    goalies[team] = goalie

# %%
## this associates a list of offensive players and a list of goalies (and their minutes) with each team in every meeting

teamPlayers1 = []
teamPlayers2 = []
teamGoalies1 = []
teamGoalies2 = []

for index, row in results.iterrows():
    team1 = row[9]
    team2 = row[10]
    date = row[13]
    
    if date in games[team1].keys():
        teamPlayers1.append(games[team1][date])
    else:
        teamPlayers1.append({})
    if date in games[team2].keys():
        teamPlayers2.append(games[team2][date])
    else:
        teamPlayers2.append({})
        
    if date in goalies[team1].keys():
        teamGoalies1.append(goalies[team1][date])
    else:
        teamGoalies1.append({})
    if date in goalies[team2].keys():
        teamGoalies2.append(goalies[team2][date])
    else:
        teamGoalies2.append({})   
        
results['Team 1 Players'] = teamPlayers1
results['Team 2 Players'] = teamPlayers2
results['Team 1 Goalies'] = teamGoalies1
results['Team 2 Goalies'] = teamGoalies2
results.head()
# Out:
#    Year          Club              Date                Versus  Club Score  \
# 0  2011  Chicago Fire  Saturday, Mar 19             FC Dallas           1
# 1  2011  Chicago Fire  Saturday, Mar 26  Sporting Kansas City           3
# 2  2011  Chicago Fire   Saturday, Apr 9   Seattle Sounders FC           1
# 3  2011  Chicago Fire    Friday, Apr 15      Portland Timbers           2
# 4  2011  Chicago Fire    Sunday, Apr 17             LA Galaxy           1
#
#    Opposing Score W/L/D        Team 1                Team 2  \
# 0               1     D  Chicago Fire             FC Dallas
# 1               2     W  Chicago Fire  Sporting Kansas City
# 2               2     L  Chicago Fire   Seattle Sounders FC
# 3               4     L  Chicago Fire      Portland Timbers
# 4               2     L  Chicago Fire             LA Galaxy
#
#   Team 1 Abbreviation Team 2 Abbreviation  \
# 0                 CHI                 DAL
# 1                 CHI                  KC
# 2                 CHI                 SEA
# 3                 CHI                 POR
# 4                 CHI                  LA
#
#                                       Team 1 Players  \
# 0  {u'Dominic Oduro': 29, u'Gaston Puerari': 90, ...
# 1  {u'Dominic Oduro': 1, u'Gaston Puerari': 74, u...
# 2  {u'Dominic Oduro': 7, u'Gaston Puerari': 90, u...
# 3                                                 {}
# 4  {u'Marco Pappa': 90, u'Gaston Puerari': 70, u'...
#
#                                       Team 2 Players  shortdate  \
# 0  {u'Ruben Luna': 25, u'Jeremy Hall': 90, u'Andr...  3/19/2011
# 1  {u'C.J. Sapong': 90, u'Birahim Diop': 6, u'Oma...  3/26/2011
# 2  {u'Servando Carrasco': 9, u'Nate Jaqua': 26, u...   4/9/2011
# 3                                                 {}  4/15/2011
# 4  {u'Chad Barrett': 77, u'Michael Stephens': 90,...  4/17/2011
#
#           Team 1 Goalies             Team 2 Goalies
# 0  {u'Sean Johnson': 90}     {u'Kevin Hartman': 90}
# 1  {u'Sean Johnson': 90}     {u'Jimmy Nielsen': 90}
# 2  {u'Sean Johnson': 90}      {u'Kasey Keller': 90}
# 3                     {}                         {}
# 4    {u'Jon Conway': 90}  {u'Donovan Ricketts': 90}

# %%
## this code normalizes all of the player statistics by how many minutes the player played

players = players[players['MINS'] != 0]
players = players[players['SOG'] != '0/0']

finalResults = pd.DataFrame()
people = players['Player']
years = players['Year']
assists = []
shots = []
shotsOnGoal = []
gameWinningGoals = []
pkAverage = []
homeGoals = []
roadGoals = []

for index, row in players.iterrows():
    minutes = float(row[6])/90
    if minutes == 0:
        print row[0]
    assists.append(row[8] / minutes)
    shots.append(row[9]/ minutes)
    shotsOnGoal.append(int(row[10])/ minutes)
    gameWinningGoals.append(row[11]/minutes)
    percents = row[12].split('/')
    if int(percents[1]) == 0:
        pkAverage.append(0)
    else:
        pkAverage.append(int(percents[0])/float(percents[1]))
    homeGoals.append(row[13]/minutes)
    roadGoals.append(row[14]/minutes)

# %%
## this dataframe stores the results of the above cell
averagedPlayers = pd.DataFrame({'Player':people, 'Year':years, 'A/90min': assists, 'SHTS/90min': shots, 'SOG/90min' : shotsOnGoal, 'GWG/90min' : gameWinningGoals, 'PKG/A' : pkAverage, 'HmG/90min' : homeGoals, 'RdG' : roadGoals})
averagedPlayers = averagedPlayers[averagedPlayers['Year'] > '2010']
averagedPlayers = averagedPlayers.drop_duplicates(['Player','Year'])
averagedPlayers.head()
# Out:
#        A/90min  GWG/90min  HmG/90min  PKG/A             Player       RdG  \
# 5450  0.388350   0.097087   0.323625    0.8  Dwayne De Rosario  0.194175
# 5451  0.101048   0.168413   0.235778    0.5  Chris Wondolowski  0.303144
# 5452  0.158870   0.119153   0.317741    0.0      Thierry Henry  0.238305
# 5453  0.089021   0.222552   0.445104    1.0     Andres Mendoza  0.133531
# 5454  0.351562   0.195312   0.117188    0.0      Fredy Montero  0.351562
#
#       SHTS/90min  SOG/90min  Year
# 5450    3.656958   1.423948  2011
# 5451    3.671407   1.751497  2011
# 5452    2.581642   1.191527  2011
# 5453    3.293769   1.379822  2011
# 5454    4.218750   1.640625  2011

# %%
## averagedPlayerSalaries is the merging of averagedPlayers and salariesCleaned

averagedPlayerSalaries = pd.merge(salariesCleaned,averagedPlayers,how='inner',on=['Player','Year'])
print len(averagedPlayerSalaries)
averagedPlayerSalaries.head()
# Out:
# 1729
#    Year Club          Player  Salary  Compensation   A/90min  GWG/90min  \
# 0  2011  PHI      Freddy Adu  475884        594884  0.147783   0.147783
# 1  2011   NY    Juan Agudelo   55000         85000  0.131965   0.065982
# 2  2011  VAN  Mouloud Akloul  150000        150000  0.000000   0.000000
# 3  2011  COL     Andre Akpan   48000         48000  0.000000   0.000000
# 4  2011   NY  Chris Albright  100800        104133  0.000000   0.000000
#
#    HmG/90min  PKG/A       RdG  SHTS/90min  SOG/90min
# 0   0.147783      0  0.147783    2.216749   0.443350
# 1   0.329912      0  0.065982    2.903226   1.121701
# 2   0.000000      0  0.000000    0.144000   0.144000
# 3   0.187891      0  0.000000    2.818372   0.939457
# 4   0.000000      0  0.000000    0.186722   0.000000

# %%
## this returns the average player stats normalized by minutes for a certain team in a certain game

def calculator (year, dictionary):
    totalMinutes = float(0)
    totals = [0] * 7
    rows = []
    for player in dictionary.keys():
        averageGuy = averagedPlayers[averagedPlayers['Player'] == player]
        averageGuy = averageGuy[averageGuy['Year'] == str(year)]
        if not(averageGuy.empty):
            individualStats = dictionary[player] * averageGuy[['A/90min', 'GWG/90min', 'HmG/90min', 'PKG/A', 'RdG', 'SHTS/90min', 'SOG/90min']]
            if individualStats.shape[0] > 1:
                print player,year
            
            totals = np.add(totals, individualStats)
            totalMinutes += dictionary[player]
 
    return (totals/totalMinutes).values

# %%
## Calculates minutes-weighted average of goalkeeper stats for a given game

def calculatorGoalie (year, dictionary):
    totalMinutes = float(0)
    totals = [0] * 3
    rows = []
    for player in dictionary.keys():
        averageGuy = goalkeepers[goalkeepers['Player'] == player]
        averageGuy = averageGuy[averageGuy['Year'] == year]
        if not(averageGuy.empty):
            individualStats = dictionary[player] * averageGuy[['SHTS', 'SV', 'GA']]
            if individualStats.shape[0] > 1:
                print player,year
            
            totals = np.add(totals, individualStats / averageGuy['MINS'].tolist()[0])
            totalMinutes += dictionary[player]
 
    return (totals/totalMinutes).values

# %%
## this removes games where any team has no players or no goalies associated with it

resultsWithPlayers = results[results['Team 1 Players'] != {}]
resultsWithPlayers = resultsWithPlayers[resultsWithPlayers['Team 2 Players'] != {}]    
resultsWithPlayers = resultsWithPlayers[resultsWithPlayers['Team 1 Goalies'] != {}]     
resultsWithPlayers = resultsWithPlayers[resultsWithPlayers['Team 2 Goalies'] != {}]

playerMinutes1 = resultsWithPlayers['Team 1 Players'].values
playerYears1 = resultsWithPlayers['Year'].values
stats1 = []
for i in range(len(playerMinutes1)):
    stats1.append(calculator(playerYears1[i], playerMinutes1[i])[0].tolist())

# %%
## storing team stats (player-averaged stats) for all games

playerMinutes2 = resultsWithPlayers['Team 2 Players'].values
playerYears2 = resultsWithPlayers['Year'].values
stats2 = []
for i in range(len(playerMinutes2)):
    stats2.append(calculator(playerYears2[i], playerMinutes2[i])[0].tolist())

# %%
## calculates team goalkeeper stats (goalkeeper stats averaged) for all games

goalkeepers = goalkeepers.drop_duplicates()

goalieMinutes1 = resultsWithPlayers['Team 1 Goalies'].values
goalieYears = resultsWithPlayers['Year'].values
goalieStats1 = []
for i in range(len(goalieMinutes1)):
    goalieStats1.append(calculatorGoalie(goalieYears[i], goalieMinutes1[i])[0].tolist())

goalieMinutes2 = resultsWithPlayers['Team 2 Goalies'].values
goalieStats2 = []
for i in range(len(goalieMinutes2)):
    goalieStats2.append(calculatorGoalie(goalieYears[i], goalieMinutes2[i])[0].tolist())

# %%
## creating dataframes to predict a team's score by their offensive stats and the opposing goalie's stats

finalResults1 = pd.DataFrame()
finalResults2 = pd.DataFrame()

finalResults1['Score'] = resultsWithPlayers['Club Score'].tolist()
finalResults2['Score'] = resultsWithPlayers['Opposing Score'].tolist()

finalResults1['A'] = list(zip(*stats1)[0])
finalResults1['GWG'] = list(zip(*stats1)[1])
finalResults1['HmG'] = list(zip(*stats1)[2])
finalResults1['PKG'] = list(zip(*stats1)[3])
finalResults1['RdG'] = list(zip(*stats1)[4])
finalResults1['SHTS'] = list(zip(*stats1)[5])
finalResults1['SOG'] = list(zip(*stats1)[6])

finalResults2['A'] = list(zip(*stats2)[0])
finalResults2['GWG'] = list(zip(*stats2)[1])
finalResults2['HmG'] = list(zip(*stats2)[2])
finalResults2['PKG'] = list(zip(*stats2)[3])
finalResults2['RdG'] = list(zip(*stats2)[4])
finalResults2['SHTS'] = list(zip(*stats2)[5])
finalResults2['SOG'] = list(zip(*stats2)[6])

finalResults2['GSHTS'] = list(zip(*goalieStats1)[0])
finalResults2['SV'] = list(zip(*goalieStats1)[1])
finalResults2['GA'] = list(zip(*goalieStats1)[2])

finalResults1['GSHTS'] = list(zip(*goalieStats2)[0])
finalResults1['SV'] = list(zip(*goalieStats2)[1])
finalResults1['GA'] = list(zip(*goalieStats2)[2])

# %%
## this code splits the finalResults 1 and 2 dataframes into three csvs for training, testing and final validation

endResults  = finalResults1.append(finalResults2,  ignore_index=True)

### RERUN NONE OF THIS CODE. 

#A, Y = sklearn.cross_validation.train_test_split(endResults.values, train_size = .5)
#finalResultsA = pd.DataFrame(A)
#finalResultsA.columns = endResults.columns
#B, C = sklearn.cross_validation.train_test_split(Y, train_size = .5)
#finalResultsB = pd.DataFrame(B)
#finalResultsC = pd.DataFrame(C)
#finalResultsB.columns = endResults.columns
#finalResultsC.columns = endResults.columns

#finalResultsA.to_csv('ScoreResultsA.csv')
#finalResultsB.to_csv('ScoreResultsB.csv')
#finalResultsC.to_csv('ScoreResultsC.csv')

### RERUNNING IT WILL RECREATE OUR DATA SPLITS. WE DON'T WANT THAT.

# %%
## this creates a dataframe with the score differential and the team statistics for both teams

finalResults = pd.DataFrame()

finalResults['Score Difference'] = (resultsWithPlayers['Club Score'] - resultsWithPlayers['Opposing Score']).tolist()

finalResults['A1'] = list(zip(*stats1)[0])
finalResults['GWG1'] = list(zip(*stats1)[1])
finalResults['HmG1'] = list(zip(*stats1)[2])
finalResults['PKG1'] = list(zip(*stats1)[3])
finalResults['RdG1'] = list(zip(*stats1)[4])
finalResults['SHTS1'] = list(zip(*stats1)[5])
finalResults['SOG1'] = list(zip(*stats1)[6])

finalResults['GSHTS1'] = list(zip(*goalieStats1)[0])
finalResults['SV1'] = list(zip(*goalieStats1)[1])
finalResults['GA1'] = list(zip(*goalieStats1)[2])

finalResults['A2'] = list(zip(*stats2)[0])
finalResults['GWG2'] = list(zip(*stats2)[1])
finalResults['HmG2'] = list(zip(*stats2)[2])
finalResults['PKG2'] = list(zip(*stats2)[3])
finalResults['RdG2'] = list(zip(*stats2)[4])
finalResults['SHTS2'] = list(zip(*stats2)[5])
finalResults['SOG2'] = list(zip(*stats2)[6])

finalResults['GSHTS2'] = list(zip(*goalieStats2)[0])
finalResults['SV2'] = list(zip(*goalieStats2)[1])
finalResults['GA2'] = list(zip(*goalieStats2)[2])

# %%
## this splits the finalResults dataframe into three csvs for training, testing and validation

### RERUN NONE OF THIS CODE. 

#A, Y = sklearn.cross_validation.train_test_split(finalResults.values, train_size = 600)
#finalResultsA = pd.DataFrame(A)
#finalResultsA.columns = finalResults.columns
#B, C = sklearn.cross_validation.train_test_split(Y, train_size = 300)
#finalResultsB = pd.DataFrame(B)
#finalResultsC = pd.DataFrame(C)
#finalResultsB.columns = finalResults.columns
#finalResultsC.columns = finalResults.columns

#finalResultsA.to_csv('finalResultsA.csv')
#finalResultsB.to_csv('finalResultsB.csv')
#finalResultsC.to_csv('finalResultsC.csv')

### RERUNNING IT WILL RECREATE OUR DATA SPLITS. WE DON'T WANT THAT.

# %%
## This gives us the proportion of total player-minutes played in a team that each player played in a season
## we did not end up using this information

player_weights = {}

for year in range(2011,2015):
    season = results[results['Year']==year]

    
    clubs = set(season['Club'])
    
    
    for club in clubs:
        roster = season[season['Club']==club]
        
        total_mins = 0
        player_weights_temp = {}
        
        for x in roster['Team 1 Players']:
            
            for y in x:
                total_mins += x[y]
                player_weights_temp[y] = 0

        for x in roster['Team 1 Players']:
            
            for y in x:
                player_weights_temp[y] += x[y]

        for y in player_weights_temp: 
            player_weights[y + str(year)] = float(player_weights_temp[y])/total_mins
        
        

player_weights
# Out:
# {'Aaron Horton2011': 7.8901688496133812e-05,
#  'Aaron Kovar2014': 0.0015037593984962407,
#  'Aaron Schoenfeld2012': 0.020375335120643431,
#  'Aaron Schoenfeld2013': 0.025742234425948172,
#  'Aaron Schoenfeld2014': 0.052597349808958624,
#  'Aaron Wheeler2013': 0.0087675350701402806,
#  'Aaron Wheeler2014': 0.018970736629667004,
#  'Adam Bedell2014': 0.044549223640354442,
#  'Adam Moffat2011': 0.10733115741903088,
#  'Adam Moffat2012': 0.12211159120796543,
#  'Adam Moffat2013': 0.081312410841654775,
#  'Adam Moffat2014': 0.068526765427610645,
#  'Adolfo Bautista2014': 0.0076899030947170993,
#  'Agustin Pelletieri2014': 0.099656142544545176,
#  'Alan Gordon2011': 0.049274568847522585,
#  'Alan Gordon2012': 0.069329660238751145,
#  'Alan Gordon2013': 0.11229529503509228,
#  'Alan Gordon2014': 0.028619362479028916,
#  'Alec Purdie2012': 0.01513014489037056,
#  'Alex Caskey2012': 0.082561078348778433,
#  'Alex Caskey2013': 0.029481692819781264,
#  'Alex Caskey2014': 0.020006317784563545,
#  'Alex Dixon2011': 0.0069043434597037406,
#  'Alex Dixon2012': 0.004884463648318617,
#  'Alex Dixon2013': 0.0020778652668416446,
#  'Alex Martinez2014': 0.037946428571428568,
#  'Alex2012': 0.04210463449593884,
#  'Alex2013': 0.096364822392219648,
#  'Alex2014': 0.11403962101636521,
#  'Alexander Lopez2013': 0.0096237970253718278,
#  'Alexander Lopez2014': 0.015484123872990984,
#  'Alvaro Rey2014': 0.026745793024957321,
#  'Alvaro Saborio2011': 0.11543702550126533,
#  'Alvaro Saborio2012': 0.15025295109612141,
#  'Alvaro Saborio2013': 0.042488860598345002,
#  'Alvaro Saborio2014': 0.076130992572586084,
#  'Andre Akpan2011': 0.040724455611390285,
#  'Andre Akpan2012': 0.031785469499657298,
#  'Andre Akpan2013': 0.0012393493415956622,
#  'Andre Akpan2014': 0.00045864546705396726,
#  'Andrea Pisanu2013': 0.035946666666666668,
#  'Andres Escobar2014': 0.098427701535944739,
#  'Andres Mendoza2011': 0.1241123560044185,
#  'Andres Romero2013': 0.097066666666666662,
#  'Andres Romero2014': 0.1336240635133624,
#  'Andrew Driver2013': 0.12948381452318461,
#  'Andrew Driver2014': 0.13024304194433556,
#  'Andrew Jacobson2011': 0.10862164515873644,
#  'Andrew Jacobson2012': 0.17011066496915092,
#  'Andrew Jacobson2013': 0.17671824018524365,
#  'Andrew Jacobson2014': 0.035717531582295736,
#  'Andrew Wenger2012': 0.056354359925788494,
#  'Andrew Wenger2013': 0.060053333333333334,
#  'Andrew Wenger2014': 0.14571140262361251,
#  'Andy Najar2011': 0.13014960571891812,
#  'Andy Najar2012': 0.12050468419462074,
#  'Andy Rose2012': 0.034119629317607411,
#  'Andy Rose2013': 0.080361388492629582,
#  'Andy Rose2014': 0.0030075187969924814,
#  'Andy Williams2011': 0.11524235935370838,
#  'Anthony Ampaipitakwong2011': 0.012318642211880646,
#  'Anthony Jackson-Hamel2014': 0.014760147601476014,
#  'Antoine Hoppenot2012': 0.033703247020139743,
#  'Antoine Hoppenot2013': 0.052104208416833664,
#  'Antoine Hoppenot2014': 0.0034308779011099897,
#  'Antonio Dovale2014': 0.038392857142857145,
#  'Arevalo Rios2013': 0.046255114748265436,
#  'Armando2014': 0.059422750424448216,
#  'Artur Aghasyan2011': 0.00058399844267081956,
#  'Arturo Alvarez2011': 0.021218610083706443,
#  'Atiba Harris2013': 0.13860569715142429,
#  'Atiba Harris2014': 0.11343353687177078,
#  'Austin Da Luz2011': 0.042597096322499813,
#  'Baggio Husidic2011': 0.043693594541052171,
#  'Baggio Husidic2014': 0.13026744300799367,
#  'Ben Zemanski2011': 0.13088245000330012,
#  'Ben Zemanski2012': 0.10423087699635752,
#  'Ben Zemanski2013': 0.062318137730358873,
#  'Ben Zemanski2014': 0.041378249500076909,
#  'Benji Joya2014': 0.037381567614125755,
#  'Benny Feilhaber2011': 0.24946846208362863,
#  'Benny Feilhaber2012': 0.15027567636876524,
#  'Benny Feilhaber2013': 0.12962962962962962,
#  'Benny Feilhaber2014': 0.15312500000000001,
#  'Bernardo Anor2011': 0.03818841723212877,
#  'Bernardo Anor2012': 0.030869398697816929,
#  'Bernardo Anor2013': 0.12733825296035695,
#  'Bernardo Anor2014': 0.12665636940086172,
#  'Bernardo Corradi2012': 0.03930890538033395,
#  'Billy Schuler2014': 0.02489431658055425,
#  'Birahim Diop2011': 0.059523809523809521,
#  'Bjorn Runstrom2012': 0.0019233235030132068,
#  'Blair Gavin2011': 0.06026004884166062,
#  'Blair Gavin2012': 0.0064110783433773558,
#  'Blake Brettschneider2011': 0.046576755840518833,
#  'Blake Brettschneider2012': 0.073086293114501863,
#  'Blake Smith2013': 0.019306666666666666,
#  'Blake Smith2014': 0.0027954825002795484,
#  'Blas Perez2012': 0.11938105964156302,
#  'Blas Perez2013': 0.15093148089674771,
#  'Blas Perez2014': 0.1413250931564119,
#  'Brad Evans2011': 0.11898115840893231,
#  'Brad Evans2012': 0.13732097725358045,
#  'Brad Evans2013': 0.085116500237755591,
#  'Brad Evans2014': 0.12518796992481204,
#  'Bradford Jamieson2014': 0.0022698115069574656,
#  'Bradlee Baladez2013': 0.002841806125670982,
#  'Bradley Wright-Phillips2013': 0.012238574748257165,
#  'Bradley Wright-Phillips2014': 0.13726002350790126,
#  'Branko Boskovic2011': 0.0051588178937283513,
#  'Branko Boskovic2012': 0.060592323964944093,
#  'Brek Shea2011': 0.14606919483809674,
#  'Brek Shea2012': 0.12153559886397022,
#  'Brian Brown2014': 0.029667003027245207,
#  'Brian Carroll2011': 0.12734756881914072,
#  'Brian Carroll2012': 0.15392519523222359,
#  'Brian Carroll2013': 0.2029058116232465,
#  'Brian Carroll2014': 0.091422805247225028,
#  'Brian Ching2011': 0.10306301782575948,
#  'Brian Ching2012': 0.075709186548938573,
#  'Brian Ching2013': 0.011154855643044619,
#  'Brian Nielsen2011': 0.00048082702247866332,
#  'Brian Ownby2012': 0.0088296073642682698,
#  'Brian Ownby2013': 0.004046369203849519,
#  'Brian Ownby2014': 0.014406115248921991,
#  'Brian Umony2011': 0.018037974683544303,
#  'Bright Dike2011': 0.028164556962025317,
#  'Bright Dike2012': 0.095006934812760055,
#  'Bruno Guarda2011': 0.030163882511281766,
#  'Bruno Guarda2012': 0.012143766526295173,
#  'Bryan Leyva2012': 0.033297424346293215,
#  'Bryan de la Fuente2013': 0.054135133292425169,
#  'C.J. Sapong2011': 0.14160401002506265,
#  'C.J. Sapong2012': 0.14465032875074715,
#  'C.J. Sapong2013': 0.064102564102564097,
#  'C.J. Sapong2014': 0.055357142857142855,
#  'Calen Carr2011': 0.033140848606577955,
#  'Calen Carr2012': 0.1122487319180913,
#  'Calum Mallace2012': 0.017857142857142856,
#  'Calum Mallace2013': 0.0038400000000000001,
#  'Calum Mallace2014': 0.071899809907189985,
#  'Cam Weaver2011': 0.12051217675119257,
#  'Cam Weaver2012': 0.013432275032876197,
#  'Cam Weaver2013': 0.050962379702537183,
#  'Cam Weaver2014': 0.010150375939849625,
#  'Carl Robinson2011': 0.0054093040028849624,
#  'Carlo Costly2011': 0.0632688927943761,
#  'Carlos Alvarez2013': 0.11992909252062453,
#  'Carlos Alvarez2014': 0.061522666245458851,
#  'Carlos Rodriguez2012': 0.089707178532954651,
#  'Carlos Ruiz2011': 0.055698482119886802,
#  'Carlos Ruiz2013': 0.018826297984997794,
#  'Casey Townsend2012': 0.061711964135612217,
#  'Casey Townsend2013': 0.022723929989704367,
#  'Cesar Diaz Pizarro2012': 0.0066574839302112028,
#  'Chad Barrett2011': 0.11101973684210527,
#  'Chad Barrett2012': 0.051159874608150469,
#  'Chad Barrett2013': 0.041086541086541084,
#  'Chad Barrett2014': 0.082706766917293228,
#  'Chandler Hoffman2012': 0.017673653925195234,
#  'Chandler Hoffman2014': 0.0014803118523635645,
#  'Charlie Davies2011': 0.083941336870808458,
#  'Charlie Davies2013': 0.0015015015015015015,
#  'Charlie Davies2014': 0.078734138510931057,
#  'Charlie Rugg2013': 0.0093999484934329126,
#  'Chris Agorsor2011': 0.0019466614755693985,
#  'Chris Birchall2011': 0.12184758771929824,
#  'Chris Birchall2012': 0.10731520490233627,
#  'Chris Pontius2011': 0.11909499594664308,
#  'Chris Pontius2012': 0.13682381384103959,
#  'Chris Pontius2013': 0.10508898367406971,
#  'Chris Pontius2014': 0.017058018321575233,
#  'Chris Rolfe2012': 0.1051122790253225,
#  'Chris Rolfe2013': 0.1266085512660855,
#  'Chris Rolfe2014': 0.13741181425713384,
#  'Chris Wondolowski2011': 0.17246099096632905,
#  'Chris Wondolowski2012': 0.14462809917355371,
#  'Chris Wondolowski2013': 0.16376397192617625,
#  'Chris Wondolowski2014': 0.12682010333489901,
#  'Christian Sivebaek2012': 0.010530749789385004,
#  'Claudio Bieler2013': 0.10398860398860399,
#  'Claudio Bieler2014': 0.004464285714285714,
#  'Clint Dempsey2013': 0.045173561578697098,
#  'Clint Dempsey2014': 0.080075187969924813,
#  'Clyde Simms2011': 0.12919153953865428,
#  'Clyde Simms2012': 0.15181433517117579,
#  'Clyde Simms2013': 0.030712530712530713,
#  'Cody Arnoux2011': 0.008759976640062294,
#  'Cole Grossman2011': 0.00094682026195360585,
#  'Cole Grossman2012': 0.038299502106472615,
#  'Cole Grossman2013': 0.011457670273711012,
#  'Cole Grossman2014': 0.016711681296421338,
#  'Collen Warner2011': 0.052559859840373757,
#  'Collen Warner2012': 0.15596011131725418,
#  'Collen Warner2013': 0.037866666666666667,
#  'Collen Warner2014': 0.19438444924406048,
#  'Collin Martin2013': 0.017281953228415945,
#  'Collin Martin2014': 0.020111614193955987,
#  'Conor Doyle2013': 0.047359905868510077,
#  'Conor Doyle2014': 0.022217542381804782,
#  'Corben Bone2011': 0.029385868368919217,
#  'Corben Bone2012': 0.0015527950310559005,
#  'Corben Bone2013': 0.00017790428749332859,
#  'Corben Bone2014': 0.00020181634712411706,
#  'Cordell Cato2013': 0.05224850532882766,
#  'Cordell Cato2014': 0.11061531235321748,
#  'Corey Ashe2011': 0.21265377855887521,
#  'Corey Ashe2012': 0.17490137140710127,
#  'Corey Ashe2013': 0.1624015748031496,
#  'Corey Ashe2014': 0.12348098784790279,
#  'Corey Hertzog2011': 0.00024041351123933166,
#  'Coy Craft2014': 0.00054530582568390444,
#  'Craig Rocastle2011': 0.038220551378446113,
#  'Cristhian Hernandez2012': 0.0016440608302507192,
#  'Cristian Maidana2014': 0.12028254288597376,
#  'Cristian Nazarit2011': 0.034338542813119086,
#  'Daigo Kobayashi2014': 0.13942822198440605,
#  'Dan Keat2011': 0.0037006578947368419,
#  'Dan Keat2012': 0.01128526645768025,
#  'Dane Richards2011': 0.13763673518451738,
#  'Daniel Antunez2013': 0.0036135542374036954,
#  'Daniel Cruz2011': 0.031905629007996199,
#  'Daniel Fragoso2014': 0.00062519537355423566,
#  'Daniel Hernandez2011': 0.15422373525453251,
#  'Daniel Hernandez2012': 0.13847811184017236,
#  'Daniel Paladini2011': 0.082049306625577814,
#  'Daniel Paladini2012': 0.041268514094601048,
#  'Daniel Paladini2013': 0.048805076202336477,
#  'Daniel Paladini2014': 0.010649540687748963,
#  'Daniele Paponi2013': 0.022720000000000001,
#  'Danny Cruz2011': 0.089505397941250314,
#  'Danny Cruz2012': 0.07994245787094123,
#  'Danny Cruz2013': 0.16157314629258518,
#  'Danny Cruz2014': 0.069223007063572151,
#  'Danny Garcia2014': 0.025629373807143505,
#  'Danny Koevermans2012': 0.17681728880157171,
#  'Danny Mwanga2011': 0.096475430923591454,
#  'Danny Mwanga2012': 0.097260748959778084,
#  'Danny Mwanga2013': 0.036656671664167917,
#  'Danny Mwanga2014': 0.00118464697520139,
#  'Darlington Nagbe2011': 0.14082278481012658,
#  'Darlington Nagbe2012': 0.21601941747572814,
#  'Darlington Nagbe2013': 0.19544131910766246,
#  'Darlington Nagbe2014': 0.16228272573450239,
#  'David Beckham2011': 0.171875,
#  'David Beckham2012': 0.15385579937304075,
#  'David Estrada2011': 0.0038381018841591066,
#  'David Estrada2012': 0.044229149115417019,
#  'David Estrada2013': 0.065145030908226348,
#  'David Estrada2014': 0.030114773086237761,
#  'David Ferreira2011': 0.01860501939672235,
#  'David Ferreira2012': 0.096464597003231803,
#  'David Ferreira2013': 0.18155983580675719,
#  'David Texeira2014': 0.063073707170771612,
#  'David Viana2012': 0.0045531197301854976,
#  'Davis Paul2011': 0.0024763372220999338,
#  'Dax McCarty2011': 0.10001202067556196,
#  'Dax McCarty2012': 0.18137168917733731,
#  'Dax McCarty2013': 0.16560805577072038,
#  'Dax McCarty2014': 0.1524095598798485,
#  'Dejan Rusmir2011': 0.060596496765030775,
#  'Deshorn Brown2013': 0.13583208395802099,
#  'Deshorn Brown2014': 0.1692465645237719,
#  'Devon Sandoval2013': 0.070973901973265432,
#  'Devon Sandoval2014': 0.029034436191762322,
#  'Diego Chara2011': 0.19715189873417721,
#  'Diego Chara2012': 0.15065880721220526,
#  'Diego Chara2013': 0.17458777885548013,
#  'Diego Chara2014': 0.15043839409321644,
#  'Diego Chaves2011': 0.08854281311908431,
#  'Diego Valeri2013': 0.13482056256062075,
#  'Diego Valeri2014': 0.159206275957545,
#  'Dillon Serna2013': 0.00097451274362818591,
#  'Dillon Serna2014': 0.10622334544305796,
#  'Dimitry Imbongo2012': 0.015643031157840749,
#  'Dimitry Imbongo2013': 0.050641550641550639,
#  'Dimitry Imbongo2014': 0.0013759364011619018,
#  'Dom Dwyer2012': 0.002390914524805738,
#  'Dom Dwyer2013': 0.064577397910731249,
#  'Dom Dwyer2014': 0.15625,
#  'Dominic Oduro2011': 0.14241690512876953,
#  'Dominic Oduro2012': 0.10373865265169613,
#  'Dominic Oduro2013': 0.20799725416166123,
#  'Dominic Oduro2014': 0.066954643628509725,
#  'Dwayne De Rosario2011': 0.10966172894096839,
#  'Dwayne De Rosario2012': 0.13939256572982775,
#  'Dwayne De Rosario2013': 0.098176202382703345,
#  'Eddie Gaven2011': 0.13271264005049707,
#  'Eddie Gaven2012': 0.1969360398314822,
#  'Eddie Gaven2013': 0.054058692294491159,
#  'Eddie Johnson2012': 0.14743049705139005,
#  'Eddie Johnson2013': 0.085592011412268187,
#  'Eddie Johnson2014': 0.14625671264609877,
#  'Edgar Mejia2013': 0.13779232290175222,
#  'Edson Buddle2012': 0.070470219435736683,
#  'Edson Buddle2013': 0.10577211394302849,
#  'Edson Buddle2014': 0.086400252724688043,
#  'Edu2012': 0.026302261823166553,
#  'Eduardo Sebrango2012': 0.013682745825602969,
#  'Ellis McLoughlin2011': 0.012044894607172188,
#  'Emery Welshman2013': 0.0092592592592592587,
#  'Emiliano Bonfigli2012': 0.013996627318718381,
#  'Emilio Renteria2011': 0.075193309136815531,
#  'Emilio Renteria2012': 0.091152815013404831,
#  'Emmanuel Ekpo2011': 0.14983430645415813,
#  'Eric Alexander2011': 0.067721518987341772,
#  'Eric Alexander2012': 0.095873786407766989,
#  'Eric Alexander2013': 0.13849728892331525,
#  'Eric Alexander2014': 0.16076792477471594,
#  'Eric Avila2011': 0.076456310679611644,
#  'Eric Avila2012': 0.058939096267190572,
#  'Eric Avila2013': 0.13465603054476036,
#  'Eric Avila2014': 0.13010315723663646,
#  'Eric Hassli2013': 0.034522681822966,
#  'Eric Stevenson2014': 0.00013059945148230379,
#  'Erick Torres2013': 0.073566509852048823,
#  'Erick Torres2014': 0.15135979993748047,
#  'Erik Friberg2011': 0.036985345429169578,
#  'Eriq Zavaleta2014': 0.08271334792122538,
#  'Ethan Finlay2012': 0.025737265415549597,
#  'Ethan Finlay2013': 0.032349407928608201,
#  'Ethan Finlay2014': 0.12616860417852208,
#  'Fabian Castillo2011': 0.0744992478821946,
#  'Fabian Castillo2012': 0.1232984036823034,
#  'Fabian Castillo2013': 0.15345753078623303,
#  'Fabian Castillo2014': 0.14714168863037352,
#  'Fabian Espindola2011': 0.13295697878138993,
#  'Fabian Espindola2012': 0.15008431703204048,
#  'Fabian Espindola2013': 0.12966692486444617,
#  'Fabian Espindola2014': 0.16773718016215647,
#  'Fanendo Adi2014': 0.10429164743885556,
#  'Federico Puppo2012': 0.012661251791686574,
#  'Felipe2012': 0.17706400742115028,
#  'Felipe2013': 0.14976,
#  'Felipe2014': 0.14223414961422343,
#  'Fernando Cardenas2012': 0.050903962046416208,
#  'Fifi Baiden2014': 0.0013820014632956669,
#  'Florent Sinama-Pongolle2014': 0.022451909273614699,
#  'Francisco Mendoza2011': 0.018546630585439906,
#  "Franck Songo'o2012": 0.11615811373092927,
#  'Fred2011': 0.038248949812071636,
#  'Fred2014': 0.0044399596367305748,
#  'Freddie Braun2012': 0.0027739251040221915,
#  'Freddy Adu2011': 0.029843066632364291,
#  'Freddy Adu2012': 0.11755034936292642,
#  'Frederic Piquionne2013': 0.029825412221144518,
#  'Frederic Piquionne2014': 0.00092293493308721734,
#  'Fredy Montero2011': 0.16782972784368458,
#  'Fredy Montero2012': 0.16385846672283066,
#  'Gabriel Farfan2011': 0.067018266014921529,
#  'Gabriel Farfan2012': 0.10933004521167283,
#  'Gabriel Farfan2013': 0.051953364696256901,
#  'Gabriel Ferrari2011': 0.00093550517279330841,
#  'Gabriel Gomez2012': 0.11713933415536375,
#  'Gabriel Torres2013': 0.038005997001499252,
#  'Gabriel Torres2014': 0.078107723898278317,
#  'Gaston Fernandez2014': 0.045531456698969387,
#  'Gaston Puerari2011': 0.04198767334360555,
#  'Gerson Mayen2011': 0.006996237872087651,
#  'Gianluca Zavarise2011': 0.11407766990291263,
#  'Gilberto2014': 0.028077753779697623,
#  'Giles Barnes2012': 0.006575239526582754,
#  'Giles Barnes2013': 0.1725721784776903,
#  'Giles Barnes2014': 0.19992159937279499,
#  'Giovani Casillas2013': 0.012408808890707029,
#  'Gorka Larrea2014': 0.020798389802079841,
#  'Graham Zusi2011': 0.12969924812030076,
#  'Graham Zusi2012': 0.214584578601315,
#  'Graham Zusi2013': 0.16856600189933524,
#  'Graham Zusi2014': 0.12053571428571429,
#  'Guillermo Franco2012': 0.0025680840898232205,
#  'Gyasi Zardes2013': 0.16044295647695081,
#  'Gyasi Zardes2014': 0.14161650054278102,
#  'Hamdi Salihi2012': 0.058476881233000905,
#  'Harrison Henao2012': 0.0018848526387936944,
#  'Harry Shipp2014': 0.13471145564168821,
#  'Hendry Thomas2012': 0.044122686771761482,
#  'Hendry Thomas2013': 0.16574212893553222,
#  'Hendry Thomas2014': 0.053712623829864581,
#  'Hernan Bernardello2013': 0.037866666666666667,
#  'Hernan Bernardello2014': 0.046964106004696408,
#  'Hogan Ephraim2013': 0.16666666666666666,
#  'Ian Christianson2014': 0.0010447956118584303,
#  'Issey Nakajima-Farran2014': 0.049759588504975957,
#  'JJ Koval2014': 0.073743541568811646,
#  'Jack McBean2012': 0.0010031347962382445,
#  'Jack McBean2013': 0.032964202935874327,
#  'Jack McInerney2011': 0.027399022382299975,
#  'Jack McInerney2012': 0.10069872585285655,
#  'Jack McInerney2013': 0.13602204408817636,
#  'Jack McInerney2014': 0.11964665101196467,
#  'Jacob Peterson2011': 0.086230495483164527,
#  'Jacob Peterson2012': 0.066347878063359234,
#  'Jacob Peterson2013': 0.042735042735042736,
#  'Jacob Peterson2014': 0.080803571428571433,
#  'Jaime Alas2013': 0.023394853132310892,
#  'Jaime Castrillon2012': 0.17126456477039068,
#  'Jaime Castrillon2013': 0.015217391304347827,
#  'Jairo Arrieta2012': 0.10371505170432785,
#  'Jairo Arrieta2013': 0.12888278702591385,
#  'Jairo Arrieta2014': 0.086659621169010645,
#  'Jamie Smith2011': 0.14018006700167504,
#  'Jamie Smith2012': 0.011394790952707333,
#  'Jamie Smith2013': 0.012368815592203899,
#  'Jared Jeffrey2013': 0.051919399911751728,
#  'Jared Jeffrey2014': 0.028219437717173845,
#  'Jason Garey2011': 0.014938488576449912,
#  'Jason Johnson2013': 0.026137357830271216,
#  'Jason Johnson2014': 0.015974127793022343,
#  'Javier Martina2011': 0.21480582524271843,
#  'Javier Morales2011': 0.035039906560249176,
#  'Javier Morales2012': 0.11163575042158516,
#  'Javier Morales2013': 0.11712285168682368,
#  'Javier Morales2014': 0.12103308575286968,
#  'Je-Vaughn Watson2011': 0.077579713783580209,
#  'Je-Vaughn Watson2012': 0.043584444861919973,
#  'Je-Vaughn Watson2013': 0.10651510367329754,
#  'Je-Vaughn Watson2014': 0.15595746614559666,
#  'Jean-Baptiste Pierazzi2014': 0.084077031470173785,
#  'Jeferson2011': 0.056390977443609019,
#  'Jeff Cunningham2011': 0.034480037872810475,
#  'Jeff Larentowicz2011': 0.27324120603015073,
#  'Jeff Larentowicz2012': 0.19319739547635367,
#  'Jeff Larentowicz2013': 0.16645911166459113,
#  'Jeff Larentowicz2014': 0.17054263565891473,
#  'Jeremiah White2012': 0.0037184254391588664,
#  'Jeremy Gagnon-Lapare2014': 0.023258414402325841,
#  'Jeremy Hall2011': 0.068482305438999289,
#  'Jeremy Hall2012': 0.056974459724950882,
#  'Jeremy Hall2013': 0.16666666666666666,
#  'Jermain Defoe2014': 0.19438444924406048,
#  'Jermaine Jones2014': 0.034704173673750192,
#  'Jerry Bengtson2012': 0.044236440569303759,
#  'Jerry Bengtson2013': 0.084630084630084632,
#  'Jerry Bengtson2014': 0.015593945879834887,
#  'Jimmy McLaughlin2012': 0.0034936292642827787,
#  'Jimmy McLaughlin2014': 0.00020181634712411706,
#  'Jimmy Medranda2014': 0.002232142857142857,
#  'Joao Plata2011': 0.10800970873786407,
#  'Joao Plata2013': 0.10089115213239974,
#  'Joao Plata2014': 0.099594868332207973,
#  'Joel Lindpere2011': 0.1716552470248828,
#  'Joel Lindpere2012': 0.13909840378880897,
#  'Joel Lindpere2013': 0.085631263713455488,
#  'Joey Gjertsen2011': 0.038324664659184229,
#  'John Stertzer2014': 0.0028696826468602296,
#  'John Thorrington2013': 0.058538020297102512,
#  'Jonathan Osorio2014': 0.12742980561555076,
#  'Jonny Steele2012': 0.064924114671163574,
#  'Jonny Steele2013': 0.14469403563129357,
#  'Jonny Steele2014': 0.033302860127987464,
#  'Jorge Claros2014': 0.04776785714285714,
#  'Jorge Villafana2011': 0.1124018216619365,
#  'Jorge Villafana2012': 0.057789296721770807,
#  'Jorge Villafana2013': 0.08345264880343628,
#  'Jorge Villafana2014': 0.12259652361175204,
#  'Jose Adolfo Valencia2013': 0.062803103782735209,
#  'Jose Manuel Rivera2013': 0.013499693188791163,
#  'Jose Mari2014': 0.12359816774601169,
#  'Jose Moreno2012': 0.0096166175150660341,
#  'Jose Villarreal2012': 0.0067711598746081503,
#  'Jose Villarreal2013': 0.078547514808138041,
#  'Jose Villarreal2014': 0.0012829369387150893,
#  'Joseph Nane2011': 0.031302345058626467,
#  'Joseph Nane2012': 0.03144276901987663,
#  'Joseph Ngwenya2011': 0.034858869481907286,
#  'Josue Martinez2012': 0.015207562679819153,
#  'Jovan Kirovski2011': 0.0030153508771929823,
#  'Juan Agudelo2011': 0.076451496574107464,
#  'Juan Agudelo2012': 0.098907256934715609,
#  'Juan Agudelo2013': 0.059104559104559105,
#  'Juan Luis Anangono2013': 0.049753899068967565,
#  'Juan Luis Anangono2014': 0.027103072064312374,
#  'Juan Pablo Angel2011': 0.10236948056233912,
#  'Juan Pablo Angel2012': 0.054637153264219668,
#  'Juan Toja2012': 0.0074368508783177328,
#  'Juan Toja2013': 0.056101556101556101,
#  'Julio Morales2013': 0.050044317174609665,
#  'Juninho2011': 0.19284539473684212,
#  'Juninho2012': 0.19122257053291536,
#  'Juninho2013': 0.1963687870203451,
#  'Juninho2014': 0.15582749432547124,
#  'Justin Braun2011': 0.12355620091083097,
#  'Justin Braun2012': 0.0057335581787521083,
#  'Justin Mapp2011': 0.091458708515564702,
#  'Justin Mapp2012': 0.10064935064935066,
#  'Justin Mapp2013': 0.13685333333333333,
#  'Justin Mapp2014': 0.10511014201051101,
#  'Justin Meram2011': 0.032191888906422599,
#  'Justin Meram2012': 0.066717732669475296,
#  'Justin Meram2013': 0.064870430753389399,
#  'Justin Meram2014': 0.11795788960247135,
#  'Kalifa Cisse2013': 0.049959049959049956,
#  'Kamani Hill2012': 0.041809458533241944,
#  'Kamani Hill2013': 0.013568215892053972,
#  'Kamani Hill2014': 0.066419207076291259,
#  'Kei Kamara2011': 0.11842105263157894,
#  'Kei Kamara2012': 0.15899581589958159,
#  'Kei Kamara2013': 0.085470085470085472,
#  'Keith Makubuya2011': 0.05461165048543689,
#  'Kelyn Rowe2012': 0.11168098474163354,
#  'Kelyn Rowe2013': 0.17731367731367731,
#  'Kelyn Rowe2014': 0.12704479437394894,
#  'Kenney Walker2014': 0.014112306325865982,
#  'Kenny Cooper2011': 0.21139240506329113,
#  'Kenny Cooper2012': 0.16102438168742325,
#  'Kenny Cooper2013': 0.13935375223660668,
#  'Kenny Cooper2014': 0.093609022556390975,
#  'Kevan George2012': 0.018919954040597473,
#  'Kevan George2013': 0.0366397803329329,
#  'Kevan George2014': 0.0092675392244532962,
#  'Kevin Burns2011': 0.086555152280258799,
#  'Khari Stephenson2011': 0.13961127840131399,
#  'Khari Stephenson2012': 0.036042240587695132,
#  'Khari Stephenson2013': 0.053150859325270527,
#  'Khari Stephenson2014': 0.053781117895725691,
#  'Kheli Dube2011': 0.0030711079612567921,
#  'Kirk Urso2012': 0.02780543852929912,
#  'Kleberson2013': 0.024549098196392786,
#  'Koke2011': 0.025106703489831784,
#  'Konrad Warzycha2012': 0.0005977286312014345,
#  'Konrad Warzycha2013': 0.022224129054401923,
#  'Kris Tyrpak2014': 0.0097530478274460777,
#  'Kurt Morsink2011': 0.0054536074876556859,
#  'Kyle Beckerman2011': 0.15767957952112127,
#  'Kyle Beckerman2012': 0.16138279932546373,
#  'Kyle Beckerman2013': 0.11950986632718014,
#  'Kyle Beckerman2014': 0.15192437542201215,
#  'Kyle Bekker2013': 0.16666666666666666,
#  'Kyle Nakazawa2011': 0.082454334962696163,
#  'Kyle Nakazawa2012': 0.014921630094043887,
#  'Kyle Porter2013': 0.095013972643035738,
#  'Kyle Porter2014': 0.0060018953353690643,
#  'Lamar Neagle2011': 0.077808792742498259,
#  'Lamar Neagle2012': 0.060992578849721708,
#  'Lamar Neagle2013': 0.12838801711840228,
#  'Lamar Neagle2014': 0.11654135338345864,
#  'Landon Donovan2011': 0.14980811403508773,
#  'Landon Donovan2012': 0.17981191222570533,
#  'Landon Donovan2013': 0.16597991243883595,
#  'Landon Donovan2014': 0.16303167867364057,
#  'Laurent Courtois2011': 0.022242756253712626,
#  'Laurent Courtois2012': 0.054146819837489493,
#  'Laurent Courtois2013': 0.015065670873036311,
#  'Lawrence Olum2012': 0.11655708308427974,
#  'Lawrence Olum2013': 0.067901234567901231,
#  'Lawrence Olum2014': 0.080357142857142863,
#  'Leandro Barrera2014': 0.12541419193497969,
#  'Lee Nguyen2012': 0.16296961148865238,
#  'Lee Nguyen2013': 0.18946218946218946,
#  'Lee Nguyen2014': 0.20165112368139429,
#  'Leo Fernandes2013': 0.027054108216432865,
#  'Leo Fernandes2014': 0.03955600403632694,
#  'Lewis Neal2012': 0.037851314596554851,
#  'Lewis Neal2013': 0.026621561994410944,
#  'Lewis Neal2014': 0.074444561440454887,
#  'Lionard Pajoy2012': 0.10199456029011786,
#  'Lionard Pajoy2013': 0.068613031328136495,
#  'Lloyd Sam2012': 0.027363620417470619,
#  'Lloyd Sam2013': 0.040433772269558479,
#  'Lloyd Sam2014': 0.15136476426799009,
#  'Logan Pause2011': 0.13339203169711644,
#  'Logan Pause2012': 0.139393215480172,
#  'Logan Pause2013': 0.053608491964656349,
#  'Logan Pause2014': 0.037553832902670115,
#  'Long Tan2012': 0.010577213659715926,
#  'Louis Beland-Goyette2014': 0.0016772895001677288,
#  'Lovel Palmer2011': 0.14050632911392405,
#  'Lovel Palmer2012': 0.089979195561719835,
#  'Lovel Palmer2013': 0.058720560152768934,
#  'Lovel Palmer2014': 0.15073212747631351,
#  'Luis Bolanos2014': 0.0031884964051266023,
#  'Luis Garrido2014': 0.058898471187769502,
#  'Luis Gil2011': 0.081175783531243911,
#  'Luis Gil2012': 0.096121416526138273,
#  'Luis Gil2013': 0.091343093570973907,
#  'Luis Gil2014': 0.084740040513166776,
#  'Luis Silva2012': 0.17681728880157171,
#  'Luis Silva2013': 0.092660685394911013,
#  'Luis Silva2014': 0.10824470885542803,
#  'Luiz Camargo2011': 0.033391915641476276,
#  'Luiz Camargo2012': 0.083975201953785453,
#  'Luiz Camargo2013': 0.0062335958005249343,
#  'Luke Moore2014': 0.19438444924406048,
#  'Luke Mulholland2014': 0.11951384199864956,
#  'Luke Rodgers2011': 0.080418319509556441,
#  'Macoumba Kandji2011': 0.0070142378559463984,
#  'Macoumba Kandji2012': 0.11703926357317303,
#  'Maicon Santos2011': 0.10284221360145673,
#  'Maicon Santos2012': 0.097159262617104863,
#  'Maicon Santos2013': 0.022475241653323846,
#  'Marcelo Saragosa2012': 0.057419159867029314,
#  'Marcelo Saragosa2013': 0.02890130901603177,
#  'Marcelo Sarvas2012': 0.12639498432601881,
#  'Marcelo Sarvas2013': 0.20306464074169456,
#  'Marcelo Sarvas2014': 0.14112306325865984,
#  'Marco Delgado2012': 0.0011908097506304286,
#  'Marco Delgado2013': 0.069680234540124092,
#  'Marco Delgado2014': 0.070084401375429817,
#  'Marco Di Vaio2012': 0.094503710575139149,
#  'Marco Di Vaio2013': 0.16853333333333334,
#  'Marco Di Vaio2014': 0.095046405009504634,
#  'Marco Pappa2011': 0.12293638564825006,
#  'Marco Pappa2012': 0.091077400860009552,
#  'Marco Pappa2014': 0.13646616541353385,
#  'Marcos Sanchez2013': 0.030739814678629209,
#  'Marcus Tracy2013': 0.0067585131271120352,
#  'Mario Martinez2013': 0.04232049453162149,
#  'Marius Obekop2013': 0.005422153369481022,
#  'Marius Obekop2014': 0.0041791824474337212,
#  'Mark Sherrod2014': 0.018326146609172873,
#  'Marko Perovic2011': 0.03543586109142452,
#  'Marlon Hairston2014': 0.057336913599747276,
#  'Martin Rivero2012': 0.17820424948594929,
#  'Martin Rivero2013': 0.04332833583208396,
#  'Martin Rivero2014': 0.036073773054079397,
#  'Marvin Chavez2011': 0.138310505898187,
#  'Marvin Chavez2012': 0.11822773186409551,
#  'Marvin Chavez2013': 0.051468676891083961,
#  'Marvin Chavez2014': 0.044576430134417006,
#  'Marvin Iraheta2013': 0.033340151360196357,
#  'Matias Perez Garcia2014': 0.0044621888210427431,
#  'Matias Sanchez2013': 0.056890338081345464,
#  'Matt Dunn2014': 0.025445451703657394,
#  'Matt Luzunaris2011': 0.0046537092800437996,
#  'Matt Stinson2011': 0.02063106796116505,
#  'Matt Watson2014': 0.11679586563307494,
#  'Matthew Fondy2013': 0.013499693188791163,
#  'Matthew Fondy2014': 0.0072351421188630487,
#  'Maurice Edu2014': 0.16347124117053483,
#  'Mauro Diaz2013': 0.016945584675297339,
#  'Mauro Diaz2014': 0.062164864127965097,
#  'Mauro Rosales2011': 0.11584089323098395,
#  'Mauro Rosales2012': 0.17186183656276327,
#  'Mauro Rosales2013': 0.12173086067522587,
#  'Maximiliano Urruti2013': 0.042192046556741025,
#  'Maximiliano Urruti2014': 0.062298107983387169,
#  'Maxwell Griffin2011': 0.0049274568847522586,
#  'Maykel Galindo2011': 0.0091837542554033726,
#  'Mehdi Ballouchy2011': 0.055896141363144608,
#  'Mehdi Ballouchy2012': 0.05808080808080808,
#  'Michael Bradley2014': 0.19438444924406048,
#  'Michael Bustamante2013': 0.014407436096049574,
#  'Michael Farfan2011': 0.094931824028813991,
#  'Michael Farfan2012': 0.16913275791204274,
#  'Michael Farfan2013': 0.19163326653306614,
#  'Michael Lahoud2011': 0.078938683915253119,
#  'Michael Lahoud2012': 0.077681874229346484,
#  'Michael Lahoud2013': 0.042585170340681364,
#  'Michael Lahoud2014': 0.012108980827447022,
#  'Michael Nanchoff2014': 0.0019996923550223041,
#  'Michael Seaton2013': 0.0083835858214443299,
#  'Michael Seaton2014': 0.0015794461408865958,
#  'Michael Stephens2011': 0.081003289473684209,
#  'Michael Stephens2012': 0.038244514106583069,
#  'Michael Stephens2013': 0.065542106618593873,
#  'Michael Videira2011': 0.02465331278890601,
#  'Michael Videira2012': 0.0023889154323936935,
#  'Michael Videira2013': 0.0049813200498132005,
#  'Micheal Azira2014': 0.065413533834586465,
#  'Miguel Montano2011': 0.0087229588276343337,
#  'Miguel Montano2012': 0.011479591836734694,
#  'Mike Fucito2011': 0.074319609211444523,
#  'Mike Fucito2012': 0.029299583911234398,
#  'Mike Fucito2013': 0.0036391993761372499,
#  'Mike Fucito2014': 0.0049318929074682952,
#  'Mike Magee2011': 0.11444627192982457,
#  'Mike Magee2012': 0.14532915360501567,
#  'Mike Magee2013': 0.13360611990748977,
#  'Mike Magee2014': 0.087223657766293428,
#  'Mikey Lopez2014': 0.074553571428571427,
#  'Miller Bolanos2012': 0.11291678341272066,
#  'Miller Bolanos2013': 0.01629508420263176,
#  'Milos Stojcev2011': 0.098997493734335834,
#  'Milovan Mirosevic2012': 0.14500191497510531,
#  'Milton Caraglio2011': 0.10630758327427356,
#  'Milton Rodriguez2011': 0.024305280658696856,
#  'Monsef Zerka2011': 0.069218048665249235,
#  'Nate Jaqua2011': 0.071179344033496156,
#  'Nathan Sturgis2011': 0.19296116504854369,
#  'Nathan Sturgis2012': 0.01653203080969378,
#  'Nathan Sturgis2013': 0.13245877061469266,
#  'Nathan Sturgis2014': 0.066520787746170679,
#  'Ned Grabavoy2011': 0.10434105509051976,
#  'Ned Grabavoy2012': 0.075210792580101174,
#  'Ned Grabavoy2013': 0.12030553787396563,
#  'Ned Grabavoy2014': 0.15209318028359217,
#  'Nelson Gonzalez2011': 0.020245279345921744,
#  'Nick LaBrocca2011': 0.18401425648472047,
#  'Nick LaBrocca2012': 0.14170636032502101,
#  'Nick LaBrocca2013': 0.082983508245877066,
#  'Nick LaBrocca2014': 0.17564365818985941,
#  'Obafemi Martins2013': 0.10175939134569663,
#  'Obafemi Martins2014': 0.13533834586466165,
#  'Olman Vargas2012': 0.047491382612026047,
#  'Olmes Garcia2013': 0.05108211330362826,
#  'Olmes Garcia2014': 0.074274139095205943,
#  'Omar Bravo2011': 0.16604010025062657,
#  'Omar Cummings2011': 0.15860552763819097,
#  'Omar Cummings2012': 0.13725154215215901,
#  'Omar Cummings2013': 0.019466316710411199,
#  'Omar Cummings2014': 0.075656605252842027,
#  'Oriol Rosell2012': 0.0071727435744172148,
#  'Oriol Rosell2013': 0.12820512820512819,
#  'Orr Barouch2011': 0.032907770195905788,
#  'Orr Barouch2012': 0.013377926421404682,
#  'Osvaldo Alonso2011': 0.18841591067690161,
#  'Osvaldo Alonso2012': 0.18955349620893008,
#  'Osvaldo Alonso2013': 0.12838801711840228,
#  'Osvaldo Alonso2014': 0.13533834586466165,
#  'Oswaldo Minda2012': 0.11480806948725134,
#  'Oswaldo Minda2013': 0.074521033612872434,
#  'Oswaldo Minda2014': 0.095217255392310102,
#  'Ousmane Dabo2011': 0.0047247814788566028,
#  'Pablo Mastroeni2011': 0.21639447236180903,
#  'Pablo Mastroeni2012': 0.012851267991775189,
#  'Pablo Mastroeni2013': 0.013649240278135463,
#  'Paolo Cardozo2011': 0.050438596491228067,
#  'Paolo Cardozo2012': 0.038175959652563742,
#  'Pat Noonan2011': 0.012212142358688068,
#  'Pat Noonan2012': 0.0089028213166144204,
#  'Patrice Bernier2012': 0.15398886827458255,
#  'Patrice Bernier2013': 0.15498666666666666,
#  'Patrice Bernier2014': 0.10622833501062283,
#  'Patrick Mullins2014': 0.087142638740253783,
#  'Patrick Nyarko2011': 0.11974466211754348,
#  'Patrick Nyarko2012': 0.15922121356903965,
#  'Patrick Nyarko2013': 0.12767597699104549,
#  'Patrick Nyarko2014': 0.048578811369509041,
#  'Paulo Jr2011': 0.013821296476542729,
#  'Paulo Jr2012': 0.0064080944350758855,
#  'Paulo Nagamura2011': 0.028314962708732096,
#  'Paulo Nagamura2012': 0.15361625821876868,
#  'Paulo Nagamura2013': 0.042735042735042736,
#  'Paulo Nagamura2014': 0.040178571428571432,
#  'Pavel Pardo2011': 0.057616112700858466,
#  'Pavel Pardo2012': 0.13712374581939799,
#  'Pedro Ribeiro2014': 0.0084762865792129168,
#  'Peguy Luyindula2013': 0.054531371030209143,
#  'Peguy Luyindula2014': 0.056157764137390626,
#  'Perry Kitchen2011': 0.14783698135455819,
#  'Perry Kitchen2012': 0.16523118766999093,
#  'Perry Kitchen2013': 0.15884688924841889,
#  'Perry Kitchen2014': 0.21796356744235021,
#  'Peter Lowry2011': 0.028481012658227847,
#  'Peter Luccin2013': 0.021155667824439534,
#  'Peter Luccin2014': 0.012814686903571753,
#  'Peter Vagenas2012': 0.058980106472401234,
#  'Peterson Joseph2012': 0.0005977286312014345,
#  'Peterson Joseph2013': 0.012345679012345678,
#  'Rafael Baca2011': 0.07856556255132767,
#  'Rafael Baca2012': 0.14416896235078053,
#  'Rafael Baca2013': 0.14842734598388355,
#  'Rafael Garcia2012': 0.00062695924764890286,
#  'Rafael Garcia2013': 0.023435488024723151,
#  'Rafael Marquez2011': 0.10602235845654526,
#  'Rafael Marquez2012': 0.082617084721978595,
#  'Rafael Robayo2012': 0.025501672240802676,
#  'Rafael2013': 0.016178849830857479,
#  'Rajko Lekic2011': 0.23387668320340185,
#  'Ramiro Corrales2011': 0.17109225294278674,
#  'Ramiro Corrales2012': 0.09986225895316804,
#  'Ramiro Corrales2013': 0.078762672212113333,
#  'Ramon Nunez2013': 0.015998315966740343,
#  'Raphael Augusto2013': 0.024635975878805706,
#  'Raul Mendiola2014': 0.0016776867660120399,
#  'Reggie Lambe2013': 0.16666666666666666,
#  'Ricardo Clark2012': 0.05936501972571858,
#  'Ricardo Clark2013': 0.18405511811023623,
#  'Ricardo Clark2014': 0.14337514700117601,
#  'Ricardo Villar2011': 0.078220251761539072,
#  'Ricardo Villar2012': 0.038585838801292724,
#  'Rob Friend2014': 0.021020428303562617,
#  'Robbie Findley2013': 0.060471037555697008,
#  'Robbie Findley2014': 0.03899392302498312,
#  'Robbie Rogers2011': 0.14257535111251382,
#  'Robbie Rogers2013': 0.035539531290239505,
#  'Robbie Rogers2014': 0.084279088127898943,
#  'Robert Earnshaw2013': 0.15740740740740741,
#  'Robert Earnshaw2014': 0.0099913867355727829,
#  'Roger Levesque2011': 0.061409630146545706,
#  'Roger Levesque2012': 0.0046335299073294017,
#  'Roger Torres2011': 0.039619243632621558,
#  'Roger Torres2012': 0.0028771064529387589,
#  'Roger Torres2013': 0.009769539078156312,
#  'Ruben Bover2013': 0.017195972114639815,
#  'Ruben Bover2014': 0.026381089199425362,
#  'Ruben Luna2011': 0.014567334336157074,
#  'Ruben Luna2012': 0.0094995592987954167,
#  'Ryan Finley2013': 0.033035867513300156,
#  'Ryan Finley2014': 0.027321037824320101,
#  'Ryan Guy2011': 0.087172218284904318,
#  'Ryan Guy2012': 0.081548916527759974,
#  'Ryan Guy2013': 0.050914550914550917,
#  'Ryan Hollingshead2014': 0.019267472507497954,
#  'Ryan Johnson2011': 0.10922330097087378,
#  'Ryan Johnson2012': 0.17681728880157171,
#  'Ryan Johnson2013': 0.11590688651794374,
#  'Ryan Pore2011': 0.021202531645569619,
#  'Ryan Smith2011': 0.056390977443609019,
#  'Ryan Smith2012': 0.083426730176520039,
#  'Saer Sene2012': 0.11360430824464675,
#  'Saer Sene2013': 0.072891072891072897,
#  'Saer Sene2014': 0.0058769753167036698,
#  'Sainey Nyassi2011': 0.11528466808410111,
#  'Sainey Nyassi2013': 0.029489630828062951,
#  'Sal Zizzo2011': 0.14651898734177216,
#  'Sal Zizzo2012': 0.10696948682385575,
#  'Sal Zizzo2013': 0.0075169738118331716,
#  'Sal Zizzo2014': 0.054017857142857145,
#  'Sam Cronin2011': 0.1355050643306871,
#  'Sam Cronin2012': 0.13957759412304868,
#  'Sam Cronin2013': 0.18715882505848713,
#  'Sam Cronin2014': 0.15359323626115548,
#  'Sam Garza2014': 0.0023485204321277596,
#  'Sammy Ochoa2011': 0.0083740404745289605,
#  'Sammy Ochoa2012': 0.0042122999157540014,
#  'Samuel Inkoom2014': 0.0026324102348109931,
#  'Samuel2014': 0.01006612059607224,
#  'Sanna Nyassi2011': 0.13253768844221106,
#  'Sanna Nyassi2012': 0.094735621521335814,
#  'Sanna Nyassi2013': 0.064960000000000004,
#  'Sanna Nyassi2014': 0.033362044214757393,
#  'Santiago Gonzalez2014': 0.005255507100525551,
#  'Santino Quaranta2011': 0.049524651779792171,
#  'Scott Caldwell2013': 0.13568113568113568,
#  'Scott Caldwell2014': 0.092646384344901397,
#  'Scott Sealy2011': 0.021078565562551329,
#  'Scott Sealy2012': 0.047497796493977083,
#  'Sean Okoli2014': 0.0015037593984962407,
#  'Sebastian Grazzini2011': 0.042923178516398854,
#  'Sebastian Grazzini2012': 0.061215957955088392,
#  'Sebastian Jaime2014': 0.014179608372721135,
#  'Sebastian Velasquez2012': 0.021247892074198988,
#  'Sebastian Velasquez2013': 0.050763844684914065,
#  'Sebastian Velasquez2014': 0.018906144496961513,
#  'Sebastien Le Toux2011': 0.16207872395163364,
#  'Sebastien Le Toux2012': 0.084546570777056657,
#  'Sebastien Le Toux2013': 0.14303607214428857,
#  'Sebastien Le Toux2014': 0.12431886982845611,
#  'Servando Carrasco2011': 0.054082344731332867,
#  'Servando Carrasco2012': 0.0012636899747262005,
#  'Servando Carrasco2013': 0.048447069116360458,
#  'Servando Carrasco2014': 0.03547628381027048,
#  'Shea Salinas2012': 0.067493112947658404,
#  'Shea Salinas2013': 0.12529243566415388,
#  'Shea Salinas2014': 0.12494128698919681,
#  'Sherjill MacDonald2012': 0.061693741041567128,
#  'Sherjill MacDonald2013': 0.034335527486212415,
#  'Simon Elliott2011': 0.1080456735529008,
#  'Sinisa Ubiparipovic2012': 0.023423005565862708,
#  'Sinisa Ubiparipovic2013': 0.00053333333333333336,
#  'Soony Saad2012': 0.010161386730424387,
#  'Soony Saad2013': 0.084995251661918333,
#  'Soony Saad2014': 0.054017857142857145,
#  'Stefan Ishizaki2014': 0.10332576729497681,
#  'Stefani Miglioranzi2011': 0.056470285567275534,
#  'Stephen King2011': 0.057705063011275703,
#  'Stephen King2012': 0.013977032336053189,
#  'Steve Neumann2014': 0.034704173673750192,
#  'Steve Zakuani2012': 0.0084245998315080027,
#  'Steve Zakuani2013': 0.0052306229196386117,
#  'Steve Zakuani2014': 0.023534840793724043,
#  'Steven Lenhart2011': 0.07391185327128387,
#  'Steven Lenhart2012': 0.083103764921946738,
#  'Steven Lenhart2013': 0.046789706264621783,
#  'Steven Lenhart2014': 0.042273367778299674,
#  'Taylor Morgan2013': 0.027777777777777776,
#  'Teal Bunbury2011': 0.13471177944862156,
#  'Teal Bunbury2012': 0.12432755528989839,
#  'Teal Bunbury2013': 0.0047483380816714148,
#  'Teal Bunbury2014': 0.18651582326861335,
#  'Teemu Tainio2011': 0.14340665945426134,
#  'Teemu Tainio2012': 0.071390984037888086,
#  'Terry Dunfield2011': 0.10922330097087378,
#  'Terry Dunfield2012': 0.17681728880157171,
#  'Terry Dunfield2013': 0.1388888888888889,
#  'Tesho Akindele2014': 0.11569571934926838,
#  'Thierry Henry2011': 0.12237047722081981,
#  'Thierry Henry2012': 0.15786704087002279,
#  'Thierry Henry2013': 0.15817195972114639,
#  'Thierry Henry2014': 0.13595402899307824,
#  'Thomas McNamara2014': 0.024257580493904345,
#  'Tim Cahill2012': 0.094720224522013688,
#  'Tim Cahill2013': 0.11789310611928737,
#  'Tim Cahill2014': 0.075747681859736182,
#  'Tom Heinemann2011': 0.077560359791699549,
#  'Tommy Thompson2014': 0.040394551432597466,
#  'Tony Cascio2012': 0.11848869088416723,
#  'Tony Cascio2013': 0.035157421289355326,
#  'Tony Cascio2014': 0.028518228145825168,
#  'Tony Tchani2011': 0.044973962442796278,
#  'Tony Tchani2012': 0.079662964381463044,
#  'Tony Tchani2013': 0.098506950403295004,
#  'Tony Tchani2014': 0.21721811234858954,
#  'Torsten Frings2012': 0.17681728880157171,
#  'Tressor Moreno2012': 0.032828282828282832,
#  'Tristan Bowen2011': 0.0039601346445779159,
#  'Tristan Bowen2012': 0.017371812832726253,
#  'Tristan Bowen2013': 0.057612326992568352,
#  'Tristan Bowen2014': 0.013157894736842105,
#  'Veljko Paunovic2011': 0.065603293028042187,
#  'Vicente Sanchez2013': 0.04332833583208396,
#  'Vicente Sanchez2014': 0.07431685357763386,
#  'Victor Estupinan2011': 0.019470662002508084,
#  'Victor Pineda2014': 0.0022968705139247776,
#  'Vincent Nogueira2014': 0.15943491422805248,
#  'Wandrille Lefevre2013': 0.0097066666666666673,
#  'Wandrille Lefevre2014': 0.060941518506094153,
#  'Wil Trapp2013': 0.11146387506435558,
#  'Wil Trapp2014': 0.18014795545077636,
#  'Will Bruin2011': 0.11260356515189555,
#  'Will Bruin2012': 0.1608115724215668,
#  'Will Bruin2013': 0.17333770778652668,
#  'Will Bruin2014': 0.1402391219129753,
#  'Will Johnson2011': 0.13899162935565504,
#  'Will Johnson2012': 0.13608768971332208,
#  'Will Johnson2013': 0.17458777885548013,
#  'Will Johnson2014': 0.12551915089986157,
#  'Yannick Djalo2014': 0.039689995302959136,
#  'Yazid Atouba2013': 0.0032615786040443573,
#  'Yordany Alvarez2012': 0.002360876897133221,
#  'Yordany Alvarez2013': 0.051718650541056649,
#  'Zach Pfeffer2011': 0.0036017494211474143,
#  'Zach Pfeffer2014': 0.0090817356205852677,
#  'Zack Schilawski2011': 0.095440585872903383}

# %%
## these normalized the player stats by the weights calculated above
## we didn't use this code

offense_adjusted = pd.DataFrame(columns = players.columns)
i=0

temp = players[players['Year']>=str(2011)]
relevant = temp[players['Year']!='M']

minutes = []
for year in range(2011,2015):
    
    temp = relevant[relevant['Year']==str(year)]
    for x in temp['Player']:
        tag = x+str(year)
        if tag in player_weights:
            minutes.append(player_weights[tag])
            temp2 = temp[temp['Player']==x]
            j = temp2.index.values

            offense_adjusted.loc[i] = temp2.loc[j[0]]
            i += 1
            
offense_adjusted['Minutes Scale']=minutes
for s in ['G', 'A', 'SHTS', 'SOG', 'GWG', 'HmG', 'RdG']:
    temp = [float(i) for i in offense_adjusted[s]]
    for X, Y, Z in zip(temp, minutes, range(len(offense_adjusted))):
        offense_adjusted[s][Z] = X*Y
    
offense_adjusted
# Out:
#                  Player  Year Club Position  GP  GS  MINS          G  \
# 0     Dwayne De Rosario  2011   DC        M  33  31  2781   1.754588
# 1     Chris Wondolowski  2011   SJ      F-M  30  30  2672   2.759376
# 2         Thierry Henry  2011   NY        F  26  26  2266   1.713187
# 3        Andres Mendoza  2011  CLB        F  29  25  2022   1.613461
# 4         Fredy Montero  2011  SEA        F  30  27  2304   2.013957
# 5        Landon Donovan  2011   LA      M-F  23  21  1915   1.797697
# 6         Dominic Oduro  2011  CHI      F-M  34  29  2633   1.709003
# 7     Sebastien Le Toux  2011  PHI      F-M  34  34  3060   1.782866
# 8             Brek Shea  2011  DAL        M  31  30  2647   1.606761
# 9        Alvaro Saborio  2011  RSL        F  23  22  1928   1.269807
# 10       Charlie Davies  2011   DC        F  26  18  1553  0.9233547
# 11     Fabian Espindola  2011  RSL        F  27  25  2096    1.32957
# 12     Juan Pablo Angel  2011  CHV        F  31  26  2314   1.023695
# 13           Kei Kamara  2011   KC        F  30  24  2201   1.065789
# 14         Luke Rodgers  2011   NY        F  23  20  1560  0.7237649
# 15         Teal Bunbury  2011   KC        F  29  20  1744   1.212406
# 16           Omar Bravo  2011   KC        F  27  26  2150   1.494361
# 17        Nick LaBrocca  2011  CHV        M  34  34  3058   1.472114
# 18         Justin Braun  2011  CHV        F  29  22  2055  0.9884496
# 19      Emilio Renteria  2011  CLB        F  18  14  1159  0.6015465
# 20        Maicon Santos  2011  DAL        F  30  24  1974  0.8227377
# 21          Marco Pappa  2011  CHI        M  29  27  2324  0.9834911
# 22         Kenny Cooper  2011  POR        F  34  29  2562   1.691139
# 23        Dane Richards  2011   NY        M  27  27  2333  0.9634571
# 24        Joel Lindpere  2011   NY        M  34  34  3048   1.201587
# 25         Chad Barrett  2011   LA        F  27  20  1583  0.7771382
# 26        Chris Pontius  2011   DC      M-F  25  25  2114   0.833665
# 27     Jeff Larentowicz  2011  COL        M  34  34  3051   1.912688
# 28        Marvin Chavez  2011  DAL        M  31  30  2521   0.829863
# 29         Juan Agudelo  2011   NY        F  27  12  1364   0.458709
# ..                  ...   ...  ...      ...  ..  ..   ...        ...
# 909       John Stertzer  2014  RSL        M   9   3   273          0
# 910        Danny Garcia  2014  DAL        M   4   4   282          0
# 911   Ryan Hollingshead  2014  DAL        M  11   4   289          0
# 912         Conor Doyle  2014   DC        F  17   1   301          0
# 913         Brian Ownby  2014  HOU        M  19   0   329          0
# 914       Jared Jeffrey  2014   DC        M  10   2   329          0
# 915       Kenney Walker  2014   LA        M   8   4   329          0
# 916         Tony Cascio  2014  HOU        M   6   4   351          0
# 917              Samuel  2014   LA        F   8   4   358          0
# 918       Alex Martinez  2014   KC        M  10   3   411          0
# 919        Jorge Claros  2014   KC        M   7   4   419          0
# 920        Gorka Larrea  2014  MTL        M   9   5   428          0
# 921         Mikey Lopez  2014   KC        M   8   5   482          0
# 922          Alvaro Rey  2014  CLB        M   9   6   491          0
# 923       Cole Grossman  2014  RSL        M  17   5   532          0
# 924       Steve Neumann  2014   NE      M-F  23   3   538          0
# 925     Andrew Jacobson  2014  DAL        M  13   5   542          0
# 926       Micheal Azira  2014  SEA        M  14   6   606          0
# 927         Logan Pause  2014  CHI        M  12   6   654          0
# 928      Tommy Thompson  2014   SJ        M  13   8   690          0
# 929        Ben Zemanski  2014  POR        M  13   7   734          0
# 930       Aaron Wheeler  2014  PHI        F  15   8   759          0
# 931   Servando Carrasco  2014  HOU        M  16   9   784          0
# 932  Hernan Bernardello  2014  MTL        M  10  10   844          0
# 933        Luis Garrido  2014  HOU        M  11  11   915          0
# 934            JJ Koval  2014   SJ        M  22   9   954          0
# 935         Adam Moffat  2014  DAL        M  20  13  1150          0
# 936       Eriq Zavaleta  2014  CHV        F  17  15  1323          0
# 937             Armando  2014   NY        M  19  14  1350          0
# 938       Oswaldo Minda  2014  CHV        M  20  20  1613          0
#
#               A         SHTS         SOG         GWG PKG/A        HmG  \
# 0      1.315941     12.39178    4.825116   0.3289852   4/5   1.096617
# 1      0.517383     18.79825    8.967972    0.862305   1/2   1.207227
# 2     0.4894819     7.954081    3.671114   0.3671114   0/1  0.9789638
# 3     0.2482247     9.184314    3.847483   0.6205618   5/5   1.241124
# 4      1.510468     18.12561    7.048849   0.8391486   0/1  0.5034892
# 5     0.4494243     6.291941    3.445587   0.5992325   4/4   1.198465
# 6     0.2848338     11.10852    5.696676   0.4272507   0/0  0.8545014
# 7      1.458709     13.12838    4.862362   0.3241574   4/4   1.458709
# 8     0.5842768     10.95519    3.359591    0.730346   0/0  0.8764152
# 9     0.2308741     7.618844    2.770489   0.4617481   3/3  0.8080592
# 10   0.08394134     2.854005    1.594885    0.251824   4/5  0.4197067
# 11    0.3988709     8.243333    4.121666    0.265914   1/1  0.6647849
# 12    0.1023695     7.984819    3.275823   0.1023695   0/0  0.5118474
# 13    0.4736842     10.77632    3.434211   0.1184211   2/2  0.7105263
# 14     0.241255     3.618824    1.608366   0.3216733   1/1  0.5629282
# 15    0.4041353     8.756266    2.963659   0.2694236   0/0  0.6735589
# 16    0.3320802     9.962406    4.151003   0.3320802   2/2   1.162281
# 17     1.104086      14.1691    4.600356   0.1840143   0/0   0.736057
# 18     0.617781     8.525378     3.58313   0.2471124   0/0  0.4942248
# 19    0.1503866     3.233312    1.278286  0.07519331   2/2  0.3759665
# 20    0.2056844     9.461484    2.571055   0.1028422   0/0  0.4113689
# 21    0.2458728     11.31015    5.040392   0.2458728   0/0  0.2458728
# 22    0.4227848     16.48861    6.341772   0.4227848   0/0  0.8455696
# 23    0.9634571     7.019473    2.890371   0.2752735   0/0  0.4129102
# 24     1.201587     9.269383    3.776415           0   0/0  0.5149657
# 25    0.5550987     5.439967    2.109375   0.4440789   0/0  0.3330592
# 26     0.595475     6.312035      2.3819     0.23819   2/2    0.47638
# 27    0.2732412     10.10992    4.918342   0.2732412   0/1  0.5464824
# 28     0.553242     9.128493    3.872694   0.4149315   0/0  0.4149315
# 29     0.152903     3.363866    1.299675   0.0764515   0/0  0.3822575
# ..          ...          ...         ...         ...   ...        ...
# 909           0  0.008609048           0           0   0/0          0
# 910           0   0.05125875  0.05125875           0   0/0          0
# 911           0    0.1156048  0.01926747           0   0/0          0
# 912           0   0.08887017  0.04443508           0   0/0          0
# 913           0   0.01440612  0.01440612           0   0/0          0
# 914           0    0.1128778  0.02821944           0   0/0          0
# 915           0   0.02822461           0           0   0/0          0
# 916           0    0.2281458  0.02851823           0   0/0          0
# 917           0    0.1006612  0.02013224           0   0/0          0
# 918           0    0.3035714   0.1138393           0   0/0          0
# 919           0   0.04776786           0           0   0/0          0
# 920           0    0.1039919  0.04159678           0   0/0          0
# 921           0     0.521875   0.2236607           0   0/0          0
# 922           0   0.08023738  0.02674579           0   0/0          0
# 923           0   0.03342336           0           0   0/0          0
# 924           0    0.5205626   0.1735209           0   0/0          0
# 925           0   0.07143506           0           0   0/0          0
# 926           0    0.4578947  0.06541353           0   0/0          0
# 927           0   0.07510767           0           0   0/0          0
# 928           0    0.2423673  0.04039455           0   0/0          0
# 929           0    0.4137825   0.0827565           0   0/0          0
# 930           0    0.1138244  0.01897074           0   0/0          0
# 931           0    0.1773814  0.03547628           0   0/0          0
# 932           0    0.3287487  0.09392821           0   0/0          0
# 933           0    0.3533908   0.1177969           0   0/0          0
# 934           0    0.5899483  0.07374354           0   0/0          0
# 935           0    0.9593747  0.06852677           0   0/0          0
# 936           0    0.1654267  0.08271335           0   0/0          0
# 937           0    0.1782683  0.05942275           0   0/0          0
# 938           0    0.4760863           0           0   0/0          0
#
#            RdG G/90min   SC%  Minutes Scale
# 0    0.6579704    0.52  14.2       0.109662
# 1     1.552149    0.54  14.7       0.172461
# 2    0.7342229    0.56  21.5       0.122370
# 3    0.3723371    0.58  17.6       0.124112
# 4     1.510468    0.47  11.1       0.167830
# 5    0.5992325    0.56  28.6       0.149808
# 6    0.8545014    0.41  15.4       0.142417
# 7    0.3241574    0.32  13.6       0.162079
# 8     0.730346    0.37  14.7       0.146069
# 9    0.4617481    0.51  16.7       0.115437
# 10    0.503648    0.64  32.4       0.083941
# 11   0.6647849    0.43  16.1       0.132957
# 12   0.5118474    0.39  12.8       0.102369
# 13   0.3552632    0.37   9.9       0.118421
# 14   0.1608366    0.52    20       0.080418
# 15   0.5388471    0.46  13.8       0.134712
# 16   0.3320802    0.38    15       0.166040
# 17    0.736057    0.24  10.4       0.184014
# 18   0.4942248    0.35  11.6       0.123556
# 19   0.2255799    0.62  18.6       0.075193
# 20   0.4113689    0.36   8.7       0.102842
# 21   0.7376183    0.31   8.7       0.122936
# 22   0.8455696    0.28  10.3       0.211392
# 23   0.5505469    0.27  13.7       0.137637
# 24    0.686621    0.21    13       0.171655
# 25   0.4440789     0.4  14.3       0.111020
# 26    0.357285     0.3  13.2       0.119095
# 27    1.366206    0.21  18.9       0.273241
# 28   0.4149315    0.21   9.1       0.138311
# 29   0.0764515     0.4  13.6       0.076451
# ..         ...     ...   ...            ...
# 909          0       0     0       0.002870
# 910          0       0     0       0.025629
# 911          0       0     0       0.019267
# 912          0       0     0       0.022218
# 913          0       0     0       0.014406
# 914          0       0     0       0.028219
# 915          0       0     0       0.014112
# 916          0       0     0       0.028518
# 917          0       0     0       0.010066
# 918          0       0     0       0.037946
# 919          0       0     0       0.047768
# 920          0       0     0       0.020798
# 921          0       0     0       0.074554
# 922          0       0     0       0.026746
# 923          0       0     0       0.016712
# 924          0       0     0       0.034704
# 925          0       0     0       0.035718
# 926          0       0     0       0.065414
# 927          0       0     0       0.037554
# 928          0       0     0       0.040395
# 929          0       0     0       0.041378
# 930          0       0     0       0.018971
# 931          0       0     0       0.035476
# 932          0       0     0       0.046964
# 933          0       0     0       0.058898
# 934          0       0     0       0.073744
# 935          0       0     0       0.068527
# 936          0       0     0       0.082713
# 937          0       0     0       0.059423
# 938          0       0     0       0.095217
#
# [939 rows x 18 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
## loading in the training set of results

training = pd.read_csv('finalResultsA.csv')
training = training.drop('Unnamed: 0', 1)
training.head()
# Out:
#    Score Difference        A1      GWG1      HmG1      PKG1      RdG1  \
# 0                 1  0.171812  0.059487  0.092087  0.182556  0.088460
# 1                 0  0.167064  0.061132  0.095982  0.187500  0.087094
# 2                -1  0.108644  0.062788  0.067721  0.000000  0.104648
# 3                 1  0.220490  0.073950  0.070818  0.271084  0.082643
# 4                 3  0.204439  0.102398  0.191423  0.241667  0.087970
#
#       SHTS1      SOG1    GSHTS1       SV1    ...           A2      GWG2  \
# 0  2.031985  0.650034  0.041751  0.028620    ...     0.143153  0.015129
# 1  2.035874  0.652097  0.041751  0.028620    ...     0.118842  0.051547
# 2  1.989368  0.600505  0.052910  0.037566    ...     0.103826  0.013672
# 3  1.695432  0.695535  0.054815  0.036296    ...     0.183780  0.060006
# 4  2.345729  0.777010  0.051440  0.031893    ...     0.224163  0.119248
#
#        HmG2      PKG2      RdG2     SHTS2      SOG2    GSHTS2       SV2  \
# 0  0.057729  0.146628  0.034260  1.471664  0.480295  0.064422  0.044057
# 1  0.095181  0.169492  0.037943  1.776289  0.528516  0.045118  0.031987
# 2  0.095545  0.000000  0.026080  1.258243  0.448361  0.046801  0.030303
# 3  0.088983  0.205556  0.054157  1.642600  0.591518  0.041577  0.029749
# 4  0.250752  0.277778  0.158690  2.371418  1.046455  0.055556  0.036420
#
#         GA2
# 0  0.020366
# 1  0.012121
# 2  0.015488
# 3  0.011828
# 4  0.016667
#
# [5 rows x 21 columns]

# %%
# Let's get a look at what our data looks like:
for col in training.columns:
    plt.figure()
    plt.hist(training[col])
    plt.title("Distribution of " + col + " in Training Set")
    plt.ylabel("Frequency")
    plt.xlabel(col)

# %%
## looking at initial distributions of team statistics versus score differential

for col in training.columns[1:]:
    plt.figure()
    plt.scatter(training[col], training['Score Difference'])
    plt.title("Relationship between " + col + " and Score Difference")
    plt.ylabel("Score Difference")
    plt.xlabel(col)

# %%
## looking at initial distributions of difference in corresponding team statistics versus score differential
for i in range(1,11):
    plt.figure()
    plt.scatter((training[training.columns[i]]-training[training.columns[i+10]]), training['Score Difference'])
    plt.title("Relationship between (" + training.columns[i] + " - " + training.columns[i+10] + ") and Score Difference")
    plt.ylabel("Score Difference")
    plt.xlabel("(" + training.columns[i] + " - " + training.columns[i+10] + ")")

# %% [markdown]
# ## Model Building

# %%
training.columns[1:]
# Out:
# Index([u'A1', u'GWG1', u'HmG1', u'PKG1', u'RdG1', u'SHTS1', u'SOG1', u'GSHTS1', u'SV1', u'GA1', u'A2', u'GWG2', u'HmG2', u'PKG2', u'RdG2', u'SHTS2', u'SOG2', u'GSHTS2', u'SV2', u'GA2'], dtype='object')

# %%
training.columns
# Out:
# Index([u'Score Difference', u'A1', u'GWG1', u'HmG1', u'PKG1', u'RdG1', u'SHTS1', u'SOG1', u'GSHTS1', u'SV1', u'GA1', u'A2', u'GWG2', u'HmG2', u'PKG2', u'RdG2', u'SHTS2', u'SOG2', u'GSHTS2', u'SV2', u'GA2'], dtype='object')

# %%
## setting up training featureset and target set
Ytrain = training['Score Difference']
Xtrain = training.drop('Score Difference', axis=1)

# %%
## building a linear regressions
lm1 = LinearRegression()
lm1.fit(Xtrain, Ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
# The coefficients
print('Coefficients: \n', lm1.coef_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((lm1.predict(Xtrain) - Ytrain) ** 2))
# Explained variance score: 1 is perfect prediction  (This is R^2)
print('Variance score: %.2f' % lm1.score(Xtrain, Ytrain)) # This is AWFUL

mse1 = np.mean((Ytrain - lm1.predict(Xtrain)) ** 2)
print "MSE:", mse1
# Out:
# ('Coefficients: \n', array([  2.10220500e+00,   1.14755717e+00,   5.52325161e+00,
#         -4.81397627e-02,   2.50495559e+00,  -5.81444056e-01,
#          2.48345329e-01,   4.33267897e+01,  -6.32961793e+01,
#         -1.09699207e+02,  -2.03991012e+00,  -5.25386582e+00,
#         -4.05305696e+00,   1.92998569e-01,  -1.17320103e-01,
#          9.41867417e-01,  -1.98728075e+00,   8.62585388e+00,
#         -1.47060554e+01,   1.00200608e+02]))
# Residual sum of squares: 2.18
# Variance score: 0.25
# MSE: 2.17722279617

# %%
#different approach to linear model, using difference in corresponding team stats
Xtrain2 = pd.DataFrame()
for i in range(10):
    Xtrain2["(" + Xtrain.columns[i] + " - " + Xtrain.columns[i+10] + ")"] = Xtrain[Xtrain.columns[i]] - Xtrain[Xtrain.columns[i+10]]
    
lm2 = LinearRegression()
lm2.fit(Xtrain2, Ytrain)

# The coefficients
print('Coefficients: \n', lm2.coef_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((lm2.predict(Xtrain2) - Ytrain) ** 2))
# Explained variance score: 1 is perfect prediction  (This is R^2)
print('Variance score: %.2f' % lm2.score(Xtrain2, Ytrain)) # This is AWFUL

mse2 = np.mean((Ytrain - lm2.predict(Xtrain2)) ** 2)
print "MSE:", mse2
# Out:
# ('Coefficients: \n', array([  1.89362118e+00,   3.82591849e+00,   4.35872207e+00,
#         -3.36462349e-02,   1.75936680e+00,  -7.25887571e-01,
#          9.95972510e-01,   2.97039758e+01,  -3.53979805e+01,
#         -1.13083070e+02]))
# Residual sum of squares: 2.21
# Variance score: 0.23
# MSE: 2.21031187703

# %%
# Trying random forest now instead of linear regression\n
scores = []
forests = []
for i in range(1,41):
    rf1 = RandomForestRegressor(n_estimators=i)
    rf1.fit(Xtrain, Ytrain)
    scores.append(rf1.score(Xtrain, Ytrain)) # R^2 for each forest\n"
    forests.append(rf1)
scores
# Out:
# [0.33642922392509078,
#  0.56479416664074389,
#  0.70896837270601187,
#  0.76030430629519863,
#  0.75853863405611688,
#  0.80167540096214029,
#  0.8218364178247165,
#  0.80045410058203592,
#  0.81690189087519949,
#  0.81447317067652469,
#  0.8429523709864909,
#  0.81296726477500647,
#  0.82066706949235191,
#  0.84027489150117196,
#  0.86015549214196274,
#  0.85102140482752542,
#  0.85598558120751733,
#  0.84409914988704693,
#  0.86778338520000708,
#  0.84678199778272467,
#  0.85842369539511854,
#  0.86340332982213241,
#  0.8575569348758505,
#  0.86179619071826785,
#  0.86459460330838012,
#  0.86180889664291516,
#  0.86805629096399639,
#  0.86388992291421784,
#  0.86468039472628644,
#  0.87809259107376747,
#  0.85644513594990768,
#  0.85909087366360748,
#  0.87056162338341891,
#  0.86531466862063444,
#  0.86377971348217164,
#  0.86728130794778502,
#  0.87313378300278699,
#  0.87036658168429759,
#  0.86718717720401417,
#  0.87802949663024998]

# %%
# Trying random forest now instead of linear regression\n with Xtrain2
scores2 = []
for i in range(1,41):
    rf1 = RandomForestRegressor(n_estimators=i)
    rf1.fit(Xtrain2, Ytrain)
    scores2.append(rf1.score(Xtrain2, Ytrain)) # R^2 for each forest\n"

scores2
# Out:
# [0.28043169007910695,
#  0.59961763300121507,
#  0.71021276234703334,
#  0.76152925234807956,
#  0.77348997559299471,
#  0.81701639200536291,
#  0.80458003494564811,
#  0.7956855605904638,
#  0.84177240050617796,
#  0.83471627916184787,
#  0.83340733680819823,
#  0.84692549146320473,
#  0.8396283646067686,
#  0.8510922722422104,
#  0.84981150325096888,
#  0.85849685685559773,
#  0.85118994465842357,
#  0.84730302113294198,
#  0.84530293480491225,
#  0.85298722450203268,
#  0.87528803204799766,
#  0.85616645845422668,
#  0.86583218479723001,
#  0.85003768079001818,
#  0.85854462975166013,
#  0.86341282008831899,
#  0.86737744568914887,
#  0.85566439231276625,
#  0.85292074615747115,
#  0.85745516662094556,
#  0.86721271585163984,
#  0.86775982781686389,
#  0.86471826272921959,
#  0.8508108956079522,
#  0.86693271747974454,
#  0.86840795586062014,
#  0.87541162278806683,
#  0.87202149495083314,
#  0.87008231597312247,
#  0.8606112012390168]

# %%
# Trying random forest now instead of linear regression
guesses = []
for forest in forests:
    guesses.append(abs(forest.predict(Xtest) - Ytest)) # R^2 for each forest2
results = [np.mean(i) for i in guesses]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-136f5819f601> in <module>()
#       2 guesses = []
#       3 for forest in forests:
# ----> 4     guesses.append(abs(forest.predict(Xtest) - Ytest)) # R^2 for each forest2
#       5 results = [np.mean(i) for i in guesses]
#
# NameError: name 'Xtest' is not defined

# %%
## creating training set with data that includes a team's goals, offensive player stats and opposing goalie stats

trainings2 = pd.read_csv('ScoreResultsA.csv')
trainings2 = trainings2.drop('Unnamed: 0', 1)
trainings2X = trainings2.drop('Score', 1)
trainings2Y = trainings2['Score']

# %%
## random forest on new dataset (team score data, not score-differential data)

scores = []
forests2 = []
for i in range(1,61):
    rf1 = RandomForestRegressor(n_estimators=i)
    rf1.fit(trainings2X, trainings2Y)
    scores.append(rf1.score(trainings2X, trainings2Y)) # R^2 for each forest\n"
    forests2.append(rf1)
scores

# %%
## testing data for team score data (as opposed to score differential)

testing2 = pd.read_csv('ScoreResultsB.csv')
testing2 = testing2.drop('Unnamed: 0', 1)
testing2X = testing2.drop('Score', 1)
testing2Y = testing2['Score']

guesses2 = []
for forest in forests2:
    guesses2.append(forest.score(testing2X,testing2Y))
guesses2

# %%
plt.plot(guesses2)

# %%
forests2[38].feature_importances_

# %%
np.mean(abs(forests2[38].predict(testing2X) - testing2Y))

# %%
## looking at training data for score-differential

svd = sklearn.decomposition.TruncatedSVD()
temp = svd.fit_transform(Xtrain)
xs = [pair[0] for pair in temp]
ys = [pair[1] for pair in temp]
    
cm = plt.cm.get_cmap('RdYlBu')
plt.scatter(xs, ys, c = Ytrain, cmap=cm)
plt.xlabel('First Principle Component')
plt.ylabel('Second Principle Component')
plt.colorbar()
plt.title('First Two Principle Components')

# %%
inputData = {'n_neighbors' : np.arange(50) + 1}

grid = sklearn.grid_search.GridSearchCV(sklearn.neighbors.KNeighborsClassifier(), inputData, scoring = 'accuracy', cv = 10)

means = []

for d in range(1,16):
    PCs = sklearn.decomposition.TruncatedSVD(d)
    temp = PCs.fit_transform(Xtrain)
    
    grid.fit(temp, Ytrain)
    
    tempStorage = []
    
    for i in range(len(grid.grid_scores_)):
        
        tempStorage.append(grid.grid_scores_[i][1])
    
    means.append(tempStorage)

# %%
boxDF = pd.DataFrame(means)
boxDF = boxDF.T
boxDF.index = boxDF.index + 1
boxDF.columns = boxDF.columns + 1
boxDF.boxplot()
plt.xlabel('Number of Dimensions')
plt.ylabel('Accuracy Score')
plt.title('Accuracy of K-Neighbors Versus Dimension')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
import sklearn
import seaborn as sns

forest38 = RandomForestClassifier(n_estimators = 38)
forest38.fit(trainings2X.values,trainings2Y.values)
plt.xticks(rotation = 90)
sns.barplot(trainings2X.columns.values, forest38.feature_importances_)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Important of Different Features')

# %%
from sklearn.tree import DecisionTreeClassifier
import sklearn.linear_model
import sklearn.svm

def plot_decision_surface(clf, X_train, Y_train):
    plot_step=0.1
    
    if X_train.shape[1] != 2:
        raise ValueError("X_train should have exactly 2 columnns!")
    
    x_min, x_max = X_train[:, 0].min() - plot_step, X_train[:, 0].max() + plot_step
    y_min, y_max = X_train[:, 1].min() - plot_step, X_train[:, 1].max() + plot_step
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))

    clf.fit(X_train,Y_train)
    if hasattr(clf, 'predict_proba'):
        Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:,1]
    else:
        Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])    
    Z = Z.reshape(xx.shape)
    cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Reds)
    plt.scatter(X_train[:,0],X_train[:,1],c=Y_train,cmap=plt.cm.Paired)
    plt.show()
    
## your code here
svd = sklearn.decomposition.TruncatedSVD()
subsetSoccer = svd.fit_transform(trainings2X)
xs = [pair[0] for pair in temp]
ys = [pair[1] for pair in temp]

subsetX = subsetSoccer
plot_decision_surface(DecisionTreeClassifier(), subsetSoccer, trainings2Y)
plot_decision_surface(RandomForestClassifier(n_estimators=15), subsetSoccer, trainings2Y)
plot_decision_surface(sklearn.svm.SVC(C = 100, gamma = 1, probability=True), subsetSoccer, trainings2Y)
plot_decision_surface(sklearn.svm.SVC(C = 1, gamma = 1, probability=True, class_weight='auto'), subsetSoccer, trainings2Y)

# %%
model = sklearn.svm.SVC(C = 1, gamma = 1, probability=True, class_weight='auto')
model.fit(Xtrain,Ytrain)
model.score(Xtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-54c69da8343c> in <module>()
#       1 model = sklearn.svm.SVC(C = 1, gamma = 1, probability=True, class_weight='auto')
#       2 model.fit(Xtrain,Ytrain)
# ----> 3 model.score(Xtest)
#
# NameError: name 'Xtest' is not defined

# %%
# Out:
# '$             32,604.00'
